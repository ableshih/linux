# %%
import requests

url = 'https://od.cdc.gov.tw/eic/Day_Confirmation_Age_County_Gender_19CoV.json'
r = requests.get(url)
print(r.json())

[{"確定病名": "嚴重特殊傳染性肺炎", "個案研判日": "2020/01/22", "縣市": "高雄市", "性別": "女", "是否為境外移入": "是", "年齡層": "55-59", "確定病例數": "1"}, {"確定病名": "嚴重特殊傳染性肺炎", "個案研判日": "2020/01/24", "縣市": "台北市", "性別": "女", "是否為境外移入": "是", "年齡層": "50-54", "確定病例數": "1"}, {"確定病
# Out:
#   File "<ipython-input-1-64f3c5f33225>", line 7
#     [{"確定病名": "嚴重特殊傳染性肺炎", "個案研判日": "2020/01/22", "縣市": "高雄市", "性別": "女", "是否為境外移入": "是", "年齡層": "55-59", "確定病例數": "1"}, {"確定病名": "嚴重特殊傳染性肺炎", "個案研判日": "2020/01/24", "縣市": "台北市", "性別": "女", "是否為境外移入": "是", "年齡層": "50-54", "確定病例數": "1"}, {"確定病
#                                                                                                                                                                                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
import json

getDatas = [{"Country Name": "World", "Country Code": "WLD", "Year": "2000", "Numbers": "6117806174.56156"}, {"Country Name": "World", "Country Code": "WLD", "Year": "2010", "Numbers": "6894595189.85751"}, {"Country Name": "Afghanistan", "Country Code": "AFG", "Year": "2000", "Numbers": "25951672.5"}, {"Country Name": "Afghanistan", "Country Code": "AFG", "Year": "2010", "Numbers": "34385849.0"}, {"Country Name": "Albania", "Country Code": "ALB", "Year": "2000", "Numbers": "3072478.0"}, {"Country Name": "Albania", "Country Code": "ALB", "Year": "2010", "Numbers": "3205579.0"}, {"Country Name": "Algeria", "Country Code": "DZA", "Year": "2000", "Numbers": "30534041.0"}, {"Country Name": "Algeria", "Country Code": "DZA", "Year": "2010", "Numbers": "35468731.0"}, {"Country Name": "American Samoa", "Country Code": "ASM", "Year": "2000", "Numbers": "57995.0"}, {"Country Name": "American Samoa", "Country Code": "ASM", "Year": "2010", "Numbers": "69154.0"}, {"Country Name": "Andorra", "Country Code": "AND", "Year": "2000", "Numbers": "65258.0"}, {"Country Name": "Andorra", "Country Code": "AND", "Year": "2010", "Numbers": "85216.0"}, {"Country Name": "Angola", "Country Code": "AGO", "Year": "2000", "Numbers": "13926705.0"}, {"Country Name": "Angola", "Country Code": "AGO", "Year": "2010", "Numbers": "19082927.0"}, {"Country Name": "Antigua and Barbuda", "Country Code": "ATG", "Year": "2000", "Numbers": "78536.0"}, {"Country Name": "Antigua and Barbuda", "Country Code": "ATG", "Year": "2010", "Numbers": "88362.0"}, {"Country Name": "Argentina", "Country Code": "ARG", "Year": "2000", "Numbers": "36931013.0"}, {"Country Name": "Argentina", "Country Code": "ARG", "Year": "2010", "Numbers": "40412643.0"}, {"Country Name": "Armenia", "Country Code": "ARM", "Year": "2000", "Numbers": "3076653.0"}, {"Country Name": "Armenia", "Country Code": "ARM", "Year": "2010", "Numbers": "3092394.0"}, {"Country Name": "Aruba", "Country Code": "ABW", "Year": "2000", "Numbers": "91031.0"}, {"Country Name": "Aruba", "Country Code": "ABW", "Year": "2010", "Numbers": "108186.0"}, {"Country Name": "Australia", "Country Code": "AUS", "Year": "2000", "Numbers": "19153581.0"}, {"Country Name": "Australia", "Country Code": "AUS", "Year": "2010", "Numbers": "22299153.0"}, {"Country Name": "Austria", "Country Code": "AUT", "Year": "2000", "Numbers": "8012068.0"}, {"Country Name": "Austria", "Country Code": "AUT", "Year": "2010", "Numbers": "8390581.0"}, {"Country Name": "Azerbaijan", "Country Code": "AZE", "Year": "2000", "Numbers": "8048754.0"}, {"Country Name": "Azerbaijan", "Country Code": "AZE", "Year": "2010", "Numbers": "9054665.0"}, {"Country Name": "Bahamas, The", "Country Code": "BHS", "Year": "2000", "Numbers": "297992.0"}, {"Country Name": "Bahamas, The", "Country Code": "BHS", "Year": "2010", "Numbers": "343960.0"}, {"Country Name": "Bahrain", "Country Code": "BHR", "Year": "2000", "Numbers": "638335.0"}, {"Country Name": "Bahrain", "Country Code": "BHR", "Year": "2010", "Numbers": "1262544.0"}, {"Country Name": "Bangladesh", "Country Code": "BGD", "Year": "2000", "Numbers": "129592417.0"}, {"Country Name": "Bangladesh", "Country Code": "BGD", "Year": "2010", "Numbers": "148692222.0"}, {"Country Name": "Barbados", "Country Code": "BRB", "Year": "2000", "Numbers": "268357.0"}, {"Country Name": "Barbados", "Country Code": "BRB", "Year": "2010", "Numbers": "274692.0"}, {"Country Name": "Belarus", "Country Code": "BLR", "Year": "2000", "Numbers": "10005803.0"}, {"Country Name": "Belarus", "Country Code": "BLR", "Year": "2010", "Numbers": "9490381.0"}, {"Country Name": "Belgium", "Country Code": "BEL", "Year": "2000", "Numbers": "10251906.0"}, {"Country Name": "Belgium", "Country Code": "BEL", "Year": "2010", "Numbers": "10896584.0"}, {"Country Name": "Belize", "Country Code": "BLZ", "Year": "2000", "Numbers": "250079.0"}, {"Country Name": "Belize", "Country Code": "BLZ", "Year": "2010", "Numbers": "345797.0"}, {"Country Name": "Benin", "Country Code": "BEN", "Year": "2000", "Numbers": "6518442.0"}, {"Country Name": "Benin", "Country Code": "BEN", "Year": "2010", "Numbers": "8850223.0"}, {"Country Name": "Bermuda", "Country Code": "BMU", "Year": "2000", "Numbers": "62771.0"}, {"Country Name": "Bermuda", "Country Code": "BMU", "Year": "2010", "Numbers": "65548.0"}, {"Country Name": "Bhutan", "Country Code": "BTN", "Year": "2000", "Numbers": "572150.0"}, {"Country Name": "Bhutan", "Country Code": "BTN", "Year": "2010", "Numbers": "726777.0"}, {"Country Name": "Bolivia", "Country Code": "BOL", "Year": "2000", "Numbers": "8308106.0"}, {"Country Name": "Bolivia", "Country Code": "BOL", "Year": "2010", "Numbers": "9929419.0"}, {"Country Name": "Bosnia and Herzegovina", "Country Code": "BIH", "Year": "2000", "Numbers": "3694221.0"}, {"Country Name": "Bosnia and Herzegovina", "Country Code": "BIH", "Year": "2010", "Numbers": "3760484.0"}, {"Country Name": "Botswana", "Country Code": "BWA", "Year": "2000", "Numbers": "1758101.0"}, {"Country Name": "Botswana", "Country Code": "BWA", "Year": "2010", "Numbers": "2007605.0"}, {"Country Name": "Brazil", "Country Code": "BRA", "Year": "2000", "Numbers": "174425502.0"}, {"Country Name": "Brazil", "Country Code": "BRA", "Year": "2010", "Numbers": "194946268.0"}, {"Country Name": "Brunei Darussalam", "Country Code": "BRN", "Year": "2000", "Numbers": "327173.0"}, {"Country Name": "Brunei Darussalam", "Country Code": "BRN", "Year": "2010", "Numbers": "399429.0"}, {"Country Name": "Bulgaria", "Country Code": "BGR", "Year": "2000", "Numbers": "8170923.0"}, {"Country Name": "Bulgaria", "Country Code": "BGR", "Year": "2010", "Numbers": "7534721.0"}, {"Country Name": "Burkina Faso", "Country Code": "BFA", "Year": "2000", "Numbers": "12294582.0"}, {"Country Name": "Burkina Faso", "Country Code": "BFA", "Year": "2010", "Numbers": "16468841.0"}, {"Country Name": "Burundi", "Country Code": "BDI", "Year": "2000", "Numbers": "6375154.0"}, {"Country Name": "Burundi", "Country Code": "BDI", "Year": "2010", "Numbers": "8382500.0"}, {"Country Name": "Cambodia", "Country Code": "KHM", "Year": "2000", "Numbers": "12447158.0"}, {"Country Name": "Cambodia", "Country Code": "KHM", "Year": "2010", "Numbers": "14139608.0"}, {"Country Name": "Cameroon", "Country Code": "CMR", "Year": "2000", "Numbers": "15678792.0"}, {"Country Name": "Cameroon", "Country Code": "CMR", "Year": "2010", "Numbers": "19599862.0"}, {"Country Name": "Canada", "Country Code": "CAN", "Year": "2000", "Numbers": "30770661.0"}, {"Country Name": "Canada", "Country Code": "CAN", "Year": "2010", "Numbers": "34126798.0"}, {"Country Name": "Cape Verde", "Country Code": "CPV", "Year": "2000", "Numbers": "438098.0"}, {"Country Name": "Cape Verde", "Country Code": "CPV", "Year": "2010", "Numbers": "496409.0"}, {"Country Name": "Cayman Islands", "Country Code": "CYM", "Year": "2000", "Numbers": "40373.0"}, {"Country Name": "Cayman Islands", "Country Code": "CYM", "Year": "2010", "Numbers": "56660.0"}, {"Country Name": "Central African Republic", "Country Code": "CAF", "Year": "2000", "Numbers": "3701785.0"}, {"Country Name": "Central African Republic", "Country Code": "CAF", "Year": "2010", "Numbers": "4401413.0"}, {"Country Name": "Chad", "Country Code": "TCD", "Year": "2000", "Numbers": "8223089.0"}, {"Country Name": "Chad", "Country Code": "TCD", "Year": "2010", "Numbers": "11227635.0"}, {"Country Name": "Channel Islands", "Country Code": "CHI", "Year": "2000", "Numbers": "145899.0"}, {"Country Name": "Channel Islands", "Country Code": "CHI", "Year": "2010", "Numbers": "153653.0"}, {"Country Name": "Chile", "Country Code": "CHL", "Year": "2000", "Numbers": "15420422.0"}, {"Country Name": "Chile", "Country Code": "CHL", "Year": "2010", "Numbers": "17114006.0"}, {"Country Name": "China", "Country Code": "CHN", "Year": "2000", "Numbers": "1262645259.0"}, {"Country Name": "China", "Country Code": "CHN", "Year": "2010", "Numbers": "1338300543.0"}, {"Country Name": "Colombia", "Country Code": "COL", "Year": "2000", "Numbers": "39764430.0"}, {"Country Name": "Colombia", "Country Code": "COL", "Year": "2010", "Numbers": "46295998.0"}, {"Country Name": "Comoros", "Country Code": "COM", "Year": "2000", "Numbers": "563155.0"}, {"Country Name": "Comoros", "Country Code": "COM", "Year": "2010", "Numbers": "735266.0"}, {"Country Name": "Congo, Dem. Rep.", "Country Code": "COD", "Year": "2000", "Numbers": "49626496.0"}, {"Country Name": "Congo, Dem. Rep.", "Country Code": "COD", "Year": "2010", "Numbers": "65965731.0"}, {"Country Name": "Congo, Rep.", "Country Code": "COG", "Year": "2000", "Numbers": "3136743.0"}, {"Country Name": "Congo, Rep.", "Country Code": "COG", "Year": "2010", "Numbers": "4043658.0"}, {"Country Name": "Costa Rica", "Country Code": "CRI", "Year": "2000", "Numbers": "3919918.0"}, {"Country Name": "Costa Rica", "Country Code": "CRI", "Year": "2010", "Numbers": "4659270.0"}, {"Country Name": "Cote d'Ivoire", "Country Code": "CIV", "Year": "2000", "Numbers": "16581844.0"}, {"Country Name": "Cote d'Ivoire", "Country Code": "CIV", "Year": "2010", "Numbers": "19738234.0"}, {"Country Name": "Croatia", "Country Code": "HRV", "Year": "2000", "Numbers": "4426628.0"}, {"Country Name": "Croatia", "Country Code": "HRV", "Year": "2010", "Numbers": "4418192.0"}, {"Country Name": "Cuba", "Country Code": "CUB", "Year": "2000", "Numbers": "11104631.0"}, {"Country Name": "Cuba", "Country Code": "CUB", "Year": "2010", "Numbers": "11258414.0"}, {"Country Name": "Curacao", "Country Code": "CUW", "Year": "2000", "Numbers": "133982.22007303"}, {"Country Name": "Curacao", "Country Code": "CUW", "Year": "2010", "Numbers": "143265.399295012"}, {"Country Name": "Cyprus", "Country Code": "CYP", "Year": "2000", "Numbers": "943448.0"}, {"Country Name": "Cyprus", "Country Code": "CYP", "Year": "2010", "Numbers": "1103554.0"}, {"Country Name": "Czech Republic", "Country Code": "CZE", "Year": "2000", "Numbers": "10272763.0"}, {"Country Name": "Czech Republic", "Country Code": "CZE", "Year": "2010", "Numbers": "10520561.0"}, {"Country Name": "Denmark", "Country Code": "DNK", "Year": "2000", "Numbers": "5340588.0"}, {"Country Name": "Denmark", "Country Code": "DNK", "Year": "2010", "Numbers": "5547462.0"}, {"Country Name": "Djibouti", "Country Code": "DJI", "Year": "2000", "Numbers": "732112.0"}, {"Country Name": "Djibouti", "Country Code": "DJI", "Year": "2010", "Numbers": "889141.0"}, {"Country Name": "Dominica", "Country Code": "DMA", "Year": "2000", "Numbers": "70263.0"}, {"Country Name": "Dominica", "Country Code": "DMA", "Year": "2010", "Numbers": "68476.0"}, {"Country Name": "Dominican Republic", "Country Code": "DOM", "Year": "2000", "Numbers": "8592212.0"}, {"Country Name": "Dominican Republic", "Country Code": "DOM", "Year": "2010", "Numbers": "9927123.0"}, {"Country Name": "Ecuador", "Country Code": "ECU", "Year": "2000", "Numbers": "12345909.0"}, {"Country Name": "Ecuador", "Country Code": "ECU", "Year": "2010", "Numbers": "14465896.0"}, {"Country Name": "Egypt, Arab Rep.", "Country Code": "EGY", "Year": "2000", "Numbers": "67649043.0"}, {"Country Name": "Egypt, Arab Rep.", "Country Code": "EGY", "Year": "2010", "Numbers": "81121730.0"}, {"Country Name": "El Salvador", "Country Code": "SLV", "Year": "2000", "Numbers": "5941239.0"}, {"Country Name": "El Salvador", "Country Code": "SLV", "Year": "2010", "Numbers": "6193287.0"}, {"Country Name": "Equatorial Guinea", "Country Code": "GNQ", "Year": "2000", "Numbers": "520913.0"}, {"Country Name": "Equatorial Guinea", "Country Code": "GNQ", "Year": "2010", "Numbers": "700551.0"}, {"Country Name": "Eritrea", "Country Code": "ERI", "Year": "2000", "Numbers": "3668389.0"}, {"Country Name": "Eritrea", "Country Code": "ERI", "Year": "2010", "Numbers": "5254600.0"}, {"Country Name": "Estonia", "Country Code": "EST", "Year": "2000", "Numbers": "1369762.0"}, {"Country Name": "Estonia", "Country Code": "EST", "Year": "2010", "Numbers": "1340525.0"}, {"Country Name": "Ethiopia", "Country Code": "ETH", "Year": "2000", "Numbers": "65578657.0"}, {"Country Name": "Ethiopia", "Country Code": "ETH", "Year": "2010", "Numbers": "82950459.0"}, {"Country Name": "Faeroe Islands", "Country Code": "FRO", "Year": "2000", "Numbers": "46468.0"}, {"Country Name": "Faeroe Islands", "Country Code": "FRO", "Year": "2010", "Numbers": "49157.0"}, {"Country Name": "Fiji", "Country Code": "FJI", "Year": "2000", "Numbers": "812309.0"}, {"Country Name": "Fiji", "Country Code": "FJI", "Year": "2010", "Numbers": "860333.0"}, {"Country Name": "Finland", "Country Code": "FIN", "Year": "2000", "Numbers": "5176366.0"}, {"Country Name": "Finland", "Country Code": "FIN", "Year": "2010", "Numbers": "5364364.0"}, {"Country Name": "France", "Country Code": "FRA", "Year": "2000", "Numbers": "60762406.0"}, {"Country Name": "France", "Country Code": "FRA", "Year": "2010", "Numbers": "64895553.0"}, {"Country Name": "French Polynesia", "Country Code": "PYF", "Year": "2000", "Numbers": "237952.0"}, {"Country Name": "French Polynesia", "Country Code": "PYF", "Year": "2010", "Numbers": "271211.0"}, {"Country Name": "Gabon", "Country Code": "GAB", "Year": "2000", "Numbers": "1235699.0"}, {"Country Name": "Gabon", "Country Code": "GAB", "Year": "2010", "Numbers": "1505179.0"}, {"Country Name": "Gambia, The", "Country Code": "GMB", "Year": "2000", "Numbers": "1297212.0"}, {"Country Name": "Gambia, The", "Country Code": "GMB", "Year": "2010", "Numbers": "1729998.0"}, {"Country Name": "Georgia", "Country Code": "GEO", "Year": "2000", "Numbers": "4419141.0"}, {"Country Name": "Georgia", "Country Code": "GEO", "Year": "2010", "Numbers": "4452906.0"}, {"Country Name": "Germany", "Country Code": "DEU", "Year": "2000", "Numbers": "82211675.0"}, {"Country Name": "Germany", "Country Code": "DEU", "Year": "2010", "Numbers": "81777237.0"}, {"Country Name": "Ghana", "Country Code": "GHA", "Year": "2000", "Numbers": "19165661.0"}, {"Country Name": "Ghana", "Country Code": "GHA", "Year": "2010", "Numbers": "24392111.0"}, {"Country Name": "Gibraltar", "Country Code": "GIB", "Year": "2000", "Numbers": "28079.0"}, {"Country Name": "Gibraltar", "Country Code": "GIB", "Year": "2010", "Numbers": "29423.0"}, {"Country Name": "Greece", "Country Code": "GRC", "Year": "2000", "Numbers": "10918108.0"}, {"Country Name": "Greece", "Country Code": "GRC", "Year": "2010", "Numbers": "11316103.0"}, {"Country Name": "Greenland", "Country Code": "GRL", "Year": "2000", "Numbers": "56375.0"}, {"Country Name": "Greenland", "Country Code": "GRL", "Year": "2010", "Numbers": "57518.0"}, {"Country Name": "Grenada", "Country Code": "GRD", "Year": "2000", "Numbers": "101656.0"}, {"Country Name": "Grenada", "Country Code": "GRD", "Year": "2010", "Numbers": "104350.0"}, {"Country Name": "Guam", "Country Code": "GUM", "Year": "2000", "Numbers": "156090.0"}, {"Country Name": "Guam", "Country Code": "GUM", "Year": "2010", "Numbers": "179435.0"}, {"Country Name": "Guatemala", "Country Code": "GTM", "Year": "2000", "Numbers": "11237643.0"}, {"Country Name": "Guatemala", "Country Code": "GTM", "Year": "2010", "Numbers": "14389372.0"}, {"Country Name": "Guinea", "Country Code": "GIN", "Year": "2000", "Numbers": "8344849.0"}, {"Country Name": "Guinea", "Country Code": "GIN", "Year": "2010", "Numbers": "9982125.0"}, {"Country Name": "Guinea-Bissau", "Country Code": "GNB", "Year": "2000", "Numbers": "1240813.0"}, {"Country Name": "Guinea-Bissau", "Country Code": "GNB", "Year": "2010", "Numbers": "1515251.0"}, {"Country Name": "Guyana", "Country Code": "GUY", "Year": "2000", "Numbers": "733663.0"}, {"Country Name": "Guyana", "Country Code": "GUY", "Year": "2010", "Numbers": "755445.0"}, {"Country Name": "Haiti", "Country Code": "HTI", "Year": "2000", "Numbers": "8645852.0"}, {"Country Name": "Haiti", "Country Code": "HTI", "Year": "2010", "Numbers": "9993801.0"}, {"Country Name": "Honduras", "Country Code": "HND", "Year": "2000", "Numbers": "6219074.0"}, {"Country Name": "Honduras", "Country Code": "HND", "Year": "2010", "Numbers": "7600495.0"}, {"Country Name": "Hong Kong SAR, China", "Country Code": "HKG", "Year": "2000", "Numbers": "6665728.0"}, {"Country Name": "Hong Kong SAR, China", "Country Code": "HKG", "Year": "2010", "Numbers": "7068211.0"}, {"Country Name": "Hungary", "Country Code": "HUN", "Year": "2000", "Numbers": "10211157.0"}, {"Country Name": "Hungary", "Country Code": "HUN", "Year": "2010", "Numbers": "10000958.0"}, {"Country Name": "Iceland", "Country Code": "ISL", "Year": "2000", "Numbers": "281984.0"}, {"Country Name": "Iceland", "Country Code": "ISL", "Year": "2010", "Numbers": "318236.0"}, {"Country Name": "India", "Country Code": "IND", "Year": "2000", "Numbers": "1053898751.0"}, {"Country Name": "India", "Country Code": "IND", "Year": "2010", "Numbers": "1224615687.0"}, {"Country Name": "Indonesia", "Country Code": "IDN", "Year": "2000", "Numbers": "213396246.0"}, {"Country Name": "Indonesia", "Country Code": "IDN", "Year": "2010", "Numbers": "239870556.0"}, {"Country Name": "Iran, Islamic Rep.", "Country Code": "IRN", "Year": "2000", "Numbers": "65343049.0"}, {"Country Name": "Iran, Islamic Rep.", "Country Code": "IRN", "Year": "2010", "Numbers": "73973755.0"}, {"Country Name": "Iraq", "Country Code": "IRQ", "Year": "2000", "Numbers": "24314245.5"}, {"Country Name": "Iraq", "Country Code": "IRQ", "Year": "2010", "Numbers": "32031193.0"}, {"Country Name": "Ireland", "Country Code": "IRL", "Year": "2000", "Numbers": "3805338.0"}, {"Country Name": "Ireland", "Country Code": "IRL", "Year": "2010", "Numbers": "4475822.0"}, {"Country Name": "Isle of Man", "Country Code": "IMN", "Year": "2000", "Numbers": "77351.0"}, {"Country Name": "Isle of Man", "Country Code": "IMN", "Year": "2010", "Numbers": "83441.0"}, {"Country Name": "Israel", "Country Code": "ISR", "Year": "2000", "Numbers": "6289445.0"}, {"Country Name": "Israel", "Country Code": "ISR", "Year": "2010", "Numbers": "7624904.0"}, {"Country Name": "Italy", "Country Code": "ITA", "Year": "2000", "Numbers": "56943070.0"}, {"Country Name": "Italy", "Country Code": "ITA", "Year": "2010", "Numbers": "60483738.0"}, {"Country Name": "Jamaica", "Country Code": "JAM", "Year": "2000", "Numbers": "2589608.55137656"}, {"Country Name": "Jamaica", "Country Code": "JAM", "Year": "2010", "Numbers": "2702862.0"}, {"Country Name": "Japan", "Country Code": "JPN", "Year": "2000", "Numbers": "126870782.0"}, {"Country Name": "Japan", "Country Code": "JPN", "Year": "2010", "Numbers": "127451296.0"}, {"Country Name": "Jordan", "Country Code": "JOR", "Year": "2000", "Numbers": "4798164.0"}, {"Country Name": "Jordan", "Country Code": "JOR", "Year": "2010", "Numbers": "6047305.0"}, {"Country Name": "Kazakhstan", "Country Code": "KAZ", "Year": "2000", "Numbers": "14884473.0"}, {"Country Name": "Kazakhstan", "Country Code": "KAZ", "Year": "2010", "Numbers": "16323888.0"}, {"Country Name": "Kenya", "Country Code": "KEN", "Year": "2000", "Numbers": "31254620.0"}, {"Country Name": "Kenya", "Country Code": "KEN", "Year": "2010", "Numbers": "40513959.0"}, {"Country Name": "Kiribati", "Country Code": "KIR", "Year": "2000", "Numbers": "84914.0"}, {"Country Name": "Kiribati", "Country Code": "KIR", "Year": "2010", "Numbers": "100377.0"}, {"Country Name": "Korea, Dem. Rep.", "Country Code": "PRK", "Year": "2000", "Numbers": "22894724.0"}, {"Country Name": "Korea, Dem. Rep.", "Country Code": "PRK", "Year": "2010", "Numbers": "24346355.0"}, {"Country Name": "Korea, Rep.", "Country Code": "KOR", "Year": "2000", "Numbers": "47008780.0"}, {"Country Name": "Korea, Rep.", "Country Code": "KOR", "Year": "2010", "Numbers": "48875757.0"}, {"Country Name": "Kosovo", "Country Code": "KSV", "Year": "2000", "Numbers": "1700780.0"}, {"Country Name": "Kosovo", "Country Code": "KSV", "Year": "2010", "Numbers": "1815584.0"}, {"Country Name": "Kuwait", "Country Code": "KWT", "Year": "2000", "Numbers": "1941670.0"}, {"Country Name": "Kuwait", "Country Code": "KWT", "Year": "2010", "Numbers": "2736961.0"}, {"Country Name": "Kyrgyz Republic", "Country Code": "KGZ", "Year": "2000", "Numbers": "4898663.0"}, {"Country Name": "Kyrgyz Republic", "Country Code": "KGZ", "Year": "2010", "Numbers": "5448202.0"}, {"Country Name": "Lao PDR", "Country Code": "LAO", "Year": "2000", "Numbers": "5317733.0"}, {"Country Name": "Lao PDR", "Country Code": "LAO", "Year": "2010", "Numbers": "6201428.0"}, {"Country Name": "Latvia", "Country Code": "LVA", "Year": "2000", "Numbers": "2373416.0"}, {"Country Name": "Latvia", "Country Code": "LVA", "Year": "2010", "Numbers": "2239182.0"}, {"Country Name": "Lebanon", "Country Code": "LBN", "Year": "2000", "Numbers": "3742940.0"}, {"Country Name": "Lebanon", "Country Code": "LBN", "Year": "2010", "Numbers": "4227721.0"}, {"Country Name": "Lesotho", "Country Code": "LSO", "Year": "2000", "Numbers": "1964503.0"}, {"Country Name": "Lesotho", "Country Code": "LSO", "Year": "2010", "Numbers": "2171380.0"}, {"Country Name": "Liberia", "Country Code": "LBR", "Year": "2000", "Numbers": "2847730.0"}, {"Country Name": "Liberia", "Country Code": "LBR", "Year": "2010", "Numbers": "3994966.0"}, {"Country Name": "Libya", "Country Code": "LBY", "Year": "2000", "Numbers": "5231650.0"}, {"Country Name": "Libya", "Country Code": "LBY", "Year": "2010", "Numbers": "6355754.0"}, {"Country Name": "Liechtenstein", "Country Code": "LIE", "Year": "2000", "Numbers": "33620.0"}, {"Country Name": "Liechtenstein", "Country Code": "LIE", "Year": "2010", "Numbers": "36137.0"}, {"Country Name": "Lithuania", "Country Code": "LTU", "Year": "2000", "Numbers": "3500286.0"}, {"Country Name": "Lithuania", "Country Code": "LTU", "Year": "2010", "Numbers": "3287144.0"}, {"Country Name": "Luxembourg", "Country Code": "LUX", "Year": "2000", "Numbers": "437089.0"}, {"Country Name": "Luxembourg", "Country Code": "LUX", "Year": "2010", "Numbers": "507237.0"}, {"Country Name": "Macao SAR, China", "Country Code": "MAC", "Year": "2000", "Numbers": "432346.0"}, {"Country Name": "Macao SAR, China", "Country Code": "MAC", "Year": "2010", "Numbers": "544859.0"}, {"Country Name": "Macedonia, FYR", "Country Code": "MKD", "Year": "2000", "Numbers": "2009545.0"}, {"Country Name": "Macedonia, FYR", "Country Code": "MKD", "Year": "2010", "Numbers": "2060758.0"}, {"Country Name": "Madagascar", "Country Code": "MDG", "Year": "2000", "Numbers": "15364449.0"}, {"Country Name": "Madagascar", "Country Code": "MDG", "Year": "2010", "Numbers": "20714242.0"}, {"Country Name": "Malawi", "Country Code": "MWI", "Year": "2000", "Numbers": "11229217.0"}, {"Country Name": "Malawi", "Country Code": "MWI", "Year": "2010", "Numbers": "14901363.0"}, {"Country Name": "Malaysia", "Country Code": "MYS", "Year": "2000", "Numbers": "23415266.0"}, {"Country Name": "Malaysia", "Country Code": "MYS", "Year": "2010", "Numbers": "28401248.0"}, {"Country Name": "Maldives", "Country Code": "MDV", "Year": "2000", "Numbers": "273507.0"}, {"Country Name": "Maldives", "Country Code": "MDV", "Year": "2010", "Numbers": "316788.0"}, {"Country Name": "Mali", "Country Code": "MLI", "Year": "2000", "Numbers": "11295585.0"}, {"Country Name": "Mali", "Country Code": "MLI", "Year": "2010", "Numbers": "15370866.0"}, {"Country Name": "Malta", "Country Code": "MLT", "Year": "2000", "Numbers": "381720.0"}, {"Country Name": "Malta", "Country Code": "MLT", "Year": "2010", "Numbers": "416394.0"}, {"Country Name": "Marshall Islands", "Country Code": "MHL", "Year": "2000", "Numbers": "52970.0"}, {"Country Name": "Marshall Islands", "Country Code": "MHL", "Year": "2010", "Numbers": "54499.0"}, {"Country Name": "Mauritania", "Country Code": "MRT", "Year": "2000", "Numbers": "2642887.0"}, {"Country Name": "Mauritania", "Country Code": "MRT", "Year": "2010", "Numbers": "3460484.0"}, {"Country Name": "Mauritius", "Country Code": "MUS", "Year": "2000", "Numbers": "1187475.0"}, {"Country Name": "Mauritius", "Country Code": "MUS", "Year": "2010", "Numbers": "1281556.0"}, {"Country Name": "Mayotte", "Country Code": "MYT", "Year": "2000", "Numbers": "149477.0"}, {"Country Name": "Mayotte", "Country Code": "MYT", "Year": "2010", "Numbers": "204891.0"}, {"Country Name": "Mexico", "Country Code": "MEX", "Year": "2000", "Numbers": "99959895.0"}, {"Country Name": "Mexico", "Country Code": "MEX", "Year": "2010", "Numbers": "113423121.0"}, {"Country Name": "Micronesia, Fed. Sts.", "Country Code": "FSM", "Year": "2000", "Numbers": "107402.0"}, {"Country Name": "Micronesia, Fed. Sts.", "Country Code": "FSM", "Year": "2010", "Numbers": "111660.0"}, {"Country Name": "Moldova", "Country Code": "MDA", "Year": "2000", "Numbers": "3640281.0"}, {"Country Name": "Moldova", "Country Code": "MDA", "Year": "2010", "Numbers": "3562264.0"}, {"Country Name": "Monaco", "Country Code": "MCO", "Year": "2000", "Numbers": "35929.0"}, {"Country Name": "Monaco", "Country Code": "MCO", "Year": "2010", "Numbers": "35792.0"}, {"Country Name": "Mongolia", "Country Code": "MNG", "Year": "2000", "Numbers": "2412108.0"}, {"Country Name": "Mongolia", "Country Code": "MNG", "Year": "2010", "Numbers": "2756727.0"}, {"Country Name": "Montenegro", "Country Code": "MNE", "Year": "2000", "Numbers": "632987.0"}, {"Country Name": "Montenegro", "Country Code": "MNE", "Year": "2010", "Numbers": "632479.0"}, {"Country Name": "Morocco", "Country Code": "MAR", "Year": "2000", "Numbers": "28793634.0"}, {"Country Name": "Morocco", "Country Code": "MAR", "Year": "2010", "Numbers": "31951317.0"}, {"Country Name": "Mozambique", "Country Code": "MOZ", "Year": "2000", "Numbers": "18200988.0"}, {"Country Name": "Mozambique", "Country Code": "MOZ", "Year": "2010", "Numbers": "23390336.0"}, {"Country Name": "Myanmar", "Country Code": "MMR", "Year": "2000", "Numbers": "44958016.0"}, {"Country Name": "Myanmar", "Country Code": "MMR", "Year": "2010", "Numbers": "47963542.0"}, {"Country Name": "Namibia", "Country Code": "NAM", "Year": "2000", "Numbers": "1896257.0"}, {"Country Name": "Namibia", "Country Code": "NAM", "Year": "2010", "Numbers": "2283675.0"}, {"Country Name": "Nepal", "Country Code": "NPL", "Year": "2000", "Numbers": "24401577.0"}, {"Country Name": "Nepal", "Country Code": "NPL", "Year": "2010", "Numbers": "29959288.0"}, {"Country Name": "Netherlands", "Country Code": "NLD", "Year": "2000", "Numbers": "15926038.0"}, {"Country Name": "Netherlands", "Country Code": "NLD", "Year": "2010", "Numbers": "16616802.0"}, {"Country Name": "New Caledonia", "Country Code": "NCL", "Year": "2000", "Numbers": "214190.0"}, {"Country Name": "New Caledonia", "Country Code": "NCL", "Year": "2010", "Numbers": "247675.0"}, {"Country Name": "New Zealand", "Country Code": "NZL", "Year": "2000", "Numbers": "3858249.0"}, {"Country Name": "New Zealand", "Country Code": "NZL", "Year": "2010", "Numbers": "4368952.0"}, {"Country Name": "Nicaragua", "Country Code": "NIC", "Year": "2000", "Numbers": "5074236.0"}, {"Country Name": "Nicaragua", "Country Code": "NIC", "Year": "2010", "Numbers": "5789995.0"}, {"Country Name": "Niger", "Country Code": "NER", "Year": "2000", "Numbers": "10922726.0"}, {"Country Name": "Niger", "Country Code": "NER", "Year": "2010", "Numbers": "15512912.0"}, {"Country Name": "Nigeria", "Country Code": "NGA", "Year": "2000", "Numbers": "123688953.0"}, {"Country Name": "Nigeria", "Country Code": "NGA", "Year": "2010", "Numbers": "158423533.0"}, {"Country Name": "Northern Mariana Islands", "Country Code": "MNP", "Year": "2000", "Numbers": "68800.0"}, {"Country Name": "Northern Mariana Islands", "Country Code": "MNP", "Year": "2010", "Numbers": "61300.0"}, {"Country Name": "Norway", "Country Code": "NOR", "Year": "2000", "Numbers": "4491509.0"}, {"Country Name": "Norway", "Country Code": "NOR", "Year": "2010", "Numbers": "4889460.0"}, {"Country Name": "Oman", "Country Code": "OMN", "Year": "2000", "Numbers": "2264813.0"}, {"Country Name": "Oman", "Country Code": "OMN", "Year": "2010", "Numbers": "2783635.0"}, {"Country Name": "Pakistan", "Country Code": "PAK", "Year": "2000", "Numbers": "144522872.0"}, {"Country Name": "Pakistan", "Country Code": "PAK", "Year": "2010", "Numbers": "173593120.0"}, {"Country Name": "Palau", "Country Code": "PLW", "Year": "2000", "Numbers": "19943.0"}, {"Country Name": "Palau", "Country Code": "PLW", "Year": "2010", "Numbers": "20753.0"}, {"Country Name": "Panama", "Country Code": "PAN", "Year": "2000", "Numbers": "2957114.0"}, {"Country Name": "Panama", "Country Code": "PAN", "Year": "2010", "Numbers": "3517100.0"}, {"Country Name": "Papua New Guinea", "Country Code": "PNG", "Year": "2000", "Numbers": "5379566.0"}, {"Country Name": "Papua New Guinea", "Country Code": "PNG", "Year": "2010", "Numbers": "6858657.0"}, {"Country Name": "Paraguay", "Country Code": "PRY", "Year": "2000", "Numbers": "5343756.0"}, {"Country Name": "Paraguay", "Country Code": "PRY", "Year": "2010", "Numbers": "6454124.0"}, {"Country Name": "Peru", "Country Code": "PER", "Year": "2000", "Numbers": "25862636.0"}, {"Country Name": "Peru", "Country Code": "PER", "Year": "2010", "Numbers": "29076704.0"}, {"Country Name": "Philippines", "Country Code": "PHL", "Year": "2000", "Numbers": "77310782.0"}, {"Country Name": "Philippines", "Country Code": "PHL", "Year": "2010", "Numbers": "93261723.0"}, {"Country Name": "Poland", "Country Code": "POL", "Year": "2000", "Numbers": "38453975.0"}, {"Country Name": "Poland", "Country Code": "POL", "Year": "2010", "Numbers": "38184610.0"}, {"Country Name": "Portugal", "Country Code": "PRT", "Year": "2000", "Numbers": "10225968.0"}, {"Country Name": "Portugal", "Country Code": "PRT", "Year": "2010", "Numbers": "10638691.0"}, {"Country Name": "Puerto Rico", "Country Code": "PRI", "Year": "2000", "Numbers": "3814884.0"}, {"Country Name": "Puerto Rico", "Country Code": "PRI", "Year": "2010", "Numbers": "3978636.0"}, {"Country Name": "Qatar", "Country Code": "QAT", "Year": "2000", "Numbers": "591389.0"}, {"Country Name": "Qatar", "Country Code": "QAT", "Year": "2010", "Numbers": "1759773.0"}, {"Country Name": "Romania", "Country Code": "ROU", "Year": "2000", "Numbers": "22443320.0"}, {"Country Name": "Romania", "Country Code": "ROU", "Year": "2010", "Numbers": "21438772.0"}, {"Country Name": "Russian Federation", "Country Code": "RUS", "Year": "2000", "Numbers": "146303811.0"}, {"Country Name": "Russian Federation", "Country Code": "RUS", "Year": "2010", "Numbers": "141750561.0"}, {"Country Name": "Rwanda", "Country Code": "RWA", "Year": "2000", "Numbers": "8098890.0"}, {"Country Name": "Rwanda", "Country Code": "RWA", "Year": "2010", "Numbers": "10624397.0"}, {"Country Name": "Samoa", "Country Code": "WSM", "Year": "2000", "Numbers": "176689.0"}, {"Country Name": "Samoa", "Country Code": "WSM", "Year": "2010", "Numbers": "184523.0"}, {"Country Name": "San Marino", "Country Code": "SMR", "Year": "2000", "Numbers": "27590.0"}, {"Country Name": "San Marino", "Country Code": "SMR", "Year": "2010", "Numbers": "32194.0"}, {"Country Name": "Sao Tome and Principe", "Country Code": "STP", "Year": "2000", "Numbers": "141942.0"}, {"Country Name": "Sao Tome and Principe", "Country Code": "STP", "Year": "2010", "Numbers": "165476.0"}, {"Country Name": "Saudi Arabia", "Country Code": "SAU", "Year": "2000", "Numbers": "20045733.0"}, {"Country Name": "Saudi Arabia", "Country Code": "SAU", "Year": "2010", "Numbers": "27448171.0"}, {"Country Name": "Senegal", "Country Code": "SEN", "Year": "2000", "Numbers": "9506591.0"}, {"Country Name": "Senegal", "Country Code": "SEN", "Year": "2010", "Numbers": "12434371.0"}, {"Country Name": "Serbia", "Country Code": "SRB", "Year": "2000", "Numbers": "7516980.0"}, {"Country Name": "Serbia", "Country Code": "SRB", "Year": "2010", "Numbers": "7291544.0"}, {"Country Name": "Seychelles", "Country Code": "SYC", "Year": "2000", "Numbers": "82004.0"}, {"Country Name": "Seychelles", "Country Code": "SYC", "Year": "2010", "Numbers": "87900.0"}, {"Country Name": "Sierra Leone", "Country Code": "SLE", "Year": "2000", "Numbers": "4143622.0"}, {"Country Name": "Sierra Leone", "Country Code": "SLE", "Year": "2010", "Numbers": "5867991.0"}, {"Country Name": "Singapore", "Country Code": "SGP", "Year": "2000", "Numbers": "4028800.0"}, {"Country Name": "Singapore", "Country Code": "SGP", "Year": "2010", "Numbers": "5077137.0"}, {"Country Name": "Sint Maarten (Dutch part)", "Country Code": "SXM", "Year": "2000", "Numbers": "31249.3964553692"}, {"Country Name": "Sint Maarten (Dutch part)", "Country Code": "SXM", "Year": "2010", "Numbers": "38782.4582169604"}, {"Country Name": "Slovak Republic", "Country Code": "SVK", "Year": "2000", "Numbers": "5389105.0"}, {"Country Name": "Slovak Republic", "Country Code": "SVK", "Year": "2010", "Numbers": "5430919.0"}, {"Country Name": "Slovenia", "Country Code": "SVN", "Year": "2000", "Numbers": "1989743.0"}, {"Country Name": "Slovenia", "Country Code": "SVN", "Year": "2010", "Numbers": "2049786.0"}, {"Country Name": "Solomon Islands", "Country Code": "SLB", "Year": "2000", "Numbers": "409231.0"}, {"Country Name": "Solomon Islands", "Country Code": "SLB", "Year": "2010", "Numbers": "538213.0"}, {"Country Name": "Somalia", "Country Code": "SOM", "Year": "2000", "Numbers": "7399776.0"}, {"Country Name": "Somalia", "Country Code": "SOM", "Year": "2010", "Numbers": "9331819.0"}, {"Country Name": "South Africa", "Country Code": "ZAF", "Year": "2000", "Numbers": "44000833.0"}, {"Country Name": "South Africa", "Country Code": "ZAF", "Year": "2010", "Numbers": "49991171.0"}, {"Country Name": "Spain", "Country Code": "ESP", "Year": "2000", "Numbers": "40263871.0"}, {"Country Name": "Spain", "Country Code": "ESP", "Year": "2010", "Numbers": "46071716.0"}, {"Country Name": "Sri Lanka", "Country Code": "LKA", "Year": "2000", "Numbers": "18745256.0"}, {"Country Name": "Sri Lanka", "Country Code": "LKA", "Year": "2010", "Numbers": "20860221.0"}, {"Country Name": "St. Kitts and Nevis", "Country Code": "KNA", "Year": "2000", "Numbers": "44944.0"}, {"Country Name": "St. Kitts and Nevis", "Country Code": "KNA", "Year": "2010", "Numbers": "52332.0"}, {"Country Name": "St. Lucia", "Country Code": "LCA", "Year": "2000", "Numbers": "156226.0"}, {"Country Name": "St. Lucia", "Country Code": "LCA", "Year": "2010", "Numbers": "174157.0"}, {"Country Name": "St. Martin (French part)", "Country Code": "MAF", "Year": "2000", "Numbers": "28768.0"}, {"Country Name": "St. Martin (French part)", "Country Code": "MAF", "Year": "2010", "Numbers": "30518.0"}, {"Country Name": "St. Vincent and the Grenadines", "Country Code": "VCT", "Year": "2000", "Numbers": "108878.0"}, {"Country Name": "St. Vincent and the Grenadines", "Country Code": "VCT", "Year": "2010", "Numbers": "109385.0"}, {"Country Name": "Sudan", "Country Code": "SDN", "Year": "2000", "Numbers": "34188122.0"}, {"Country Name": "Sudan", "Country Code": "SDN", "Year": "2010", "Numbers": "43552468.0"}, {"Country Name": "Suriname", "Country Code": "SUR", "Year": "2000", "Numbers": "467268.0"}, {"Country Name": "Suriname", "Country Code": "SUR", "Year": "2010", "Numbers": "525617.0"}, {"Country Name": "Swaziland", "Country Code": "SWZ", "Year": "2000", "Numbers": "1011781.54924681"}, {"Country Name": "Swaziland", "Country Code": "SWZ", "Year": "2010", "Numbers": "1056634.0"}, {"Country Name": "Sweden", "Country Code": "SWE", "Year": "2000", "Numbers": "8873025.0"}, {"Country Name": "Sweden", "Country Code": "SWE", "Year": "2010", "Numbers": "9378365.0"}, {"Country Name": "Switzerland", "Country Code": "CHE", "Year": "2000", "Numbers": "7184798.0"}, {"Country Name": "Switzerland", "Country Code": "CHE", "Year": "2010", "Numbers": "7826728.0"}, {"Country Name": "Syrian Arab Republic", "Country Code": "SYR", "Year": "2000", "Numbers": "15988911.0"}, {"Country Name": "Syrian Arab Republic", "Country Code": "SYR", "Year": "2010", "Numbers": "20447464.0"}, {"Country Name": "Tajikistan", "Country Code": "TJK", "Year": "2000", "Numbers": "6173449.0"}, {"Country Name": "Tajikistan", "Country Code": "TJK", "Year": "2010", "Numbers": "6879439.0"}, {"Country Name": "Tanzania", "Country Code": "TZA", "Year": "2000", "Numbers": "34038511.0"}, {"Country Name": "Tanzania", "Country Code": "TZA", "Year": "2010", "Numbers": "44841987.0"}, {"Country Name": "Thailand", "Country Code": "THA", "Year": "2000", "Numbers": "63155209.0"}, {"Country Name": "Thailand", "Country Code": "THA", "Year": "2010", "Numbers": "69122911.0"}, {"Country Name": "Timor-Leste", "Country Code": "TLS", "Year": "2000", "Numbers": "830399.0"}, {"Country Name": "Timor-Leste", "Country Code": "TLS", "Year": "2010", "Numbers": "1124864.0"}, {"Country Name": "Togo", "Country Code": "TGO", "Year": "2000", "Numbers": "4793851.0"}, {"Country Name": "Togo", "Country Code": "TGO", "Year": "2010", "Numbers": "6028718.0"}, {"Country Name": "Tonga", "Country Code": "TON", "Year": "2000", "Numbers": "98509.0"}, {"Country Name": "Tonga", "Country Code": "TON", "Year": "2010", "Numbers": "104137.0"}, {"Country Name": "Trinidad and Tobago", "Country Code": "TTO", "Year": "2000", "Numbers": "1292853.0"}, {"Country Name": "Trinidad and Tobago", "Country Code": "TTO", "Year": "2010", "Numbers": "1341164.0"}, {"Country Name": "Tunisia", "Country Code": "TUN", "Year": "2000", "Numbers": "9563731.0"}, {"Country Name": "Tunisia", "Country Code": "TUN", "Year": "2010", "Numbers": "10549417.0"}, {"Country Name": "Turkey", "Country Code": "TUR", "Year": "2000", "Numbers": "63628548.0"}, {"Country Name": "Turkey", "Country Code": "TUR", "Year": "2010", "Numbers": "72752817.0"}, {"Country Name": "Turkmenistan", "Country Code": "TKM", "Year": "2000", "Numbers": "4502033.0"}, {"Country Name": "Turkmenistan", "Country Code": "TKM", "Year": "2010", "Numbers": "5042694.0"}, {"Country Name": "Turks and Caicos Islands", "Country Code": "TCA", "Year": "2000", "Numbers": "19538.0"}, {"Country Name": "Turks and Caicos Islands", "Country Code": "TCA", "Year": "2010", "Numbers": "39051.0"}, {"Country Name": "Tuvalu", "Country Code": "TUV", "Year": "2000", "Numbers": "9669.0"}, {"Country Name": "Tuvalu", "Country Code": "TUV", "Year": "2010", "Numbers": "10579.0"}, {"Country Name": "Uganda", "Country Code": "UGA", "Year": "2000", "Numbers": "24213638.0"}, {"Country Name": "Uganda", "Country Code": "UGA", "Year": "2010", "Numbers": "33424221.0"}, {"Country Name": "Ukraine", "Country Code": "UKR", "Year": "2000", "Numbers": "49176685.6425165"}, {"Country Name": "Ukraine", "Country Code": "UKR", "Year": "2010", "Numbers": "45871393.0"}, {"Country Name": "United Arab Emirates", "Country Code": "ARE", "Year": "2000", "Numbers": "3034035.0"}, {"Country Name": "United Arab Emirates", "Country Code": "ARE", "Year": "2010", "Numbers": "7512460.0"}, {"Country Name": "United Kingdom", "Country Code": "GBR", "Year": "2000", "Numbers": "58893073.0"}, {"Country Name": "United Kingdom", "Country Code": "GBR", "Year": "2010", "Numbers": "62232393.0"}, {"Country Name": "United States", "Country Code": "USA", "Year": "2000", "Numbers": "282162848.0"}, {"Country Name": "United States", "Country Code": "USA", "Year": "2010", "Numbers": "309349813.0"}, {"Country Name": "Uruguay", "Country Code": "URY", "Year": "2000", "Numbers": "3301552.40789493"}, {"Country Name": "Uruguay", "Country Code": "URY", "Year": "2010", "Numbers": "3357415.0"}, {"Country Name": "Uzbekistan", "Country Code": "UZB", "Year": "2000", "Numbers": "24651362.0"}, {"Country Name": "Uzbekistan", "Country Code": "UZB", "Year": "2010", "Numbers": "28228121.0"}, {"Country Name": "Vanuatu", "Country Code": "VUT", "Year": "2000", "Numbers": "185904.0"}, {"Country Name": "Vanuatu", "Country Code": "VUT", "Year": "2010", "Numbers": "240163.0"}, {"Country Name": "Venezuela, RB", "Country Code": "VEN", "Year": "2000", "Numbers": "24311905.0"}, {"Country Name": "Venezuela, RB", "Country Code": "VEN", "Year": "2010", "Numbers": "28834675.0"}, {"Country Name": "Vietnam", "Country Code": "VNM", "Year": "2000", "Numbers": "77631021.0"}, {"Country Name": "Vietnam", "Country Code": "VNM", "Year": "2010", "Numbers": "86928740.0"}, {"Country Name": "Virgin Islands (U.S.)", "Country Code": "VIR", "Year": "2000", "Numbers": "109598.0"}, {"Country Name": "Virgin Islands (U.S.)", "Country Code": "VIR", "Year": "2010", "Numbers": "110505.0"}, {"Country Name": "West Bank and Gaza", "Country Code": "PSE", "Year": "2000", "Numbers": "3004887.793994"}, {"Country Name": "West Bank and Gaza", "Country Code": "PSE", "Year": "2010", "Numbers": "4152138.0"}, {"Country Name": "Yemen, Rep.", "Country Code": "YEM", "Year": "2000", "Numbers": "17723779.0"}, {"Country Name": "Yemen, Rep.", "Country Code": "YEM", "Year": "2010", "Numbers": "24053403.0"}, {"Country Name": "Zambia", "Country Code": "ZMB", "Year": "2000", "Numbers": "10201780.0"}, {"Country Name": "Zambia", "Country Code": "ZMB", "Year": "2010", "Numbers": "12927443.0"}, {"Country Name": "Zimbabwe", "Country Code": "ZWE", "Year": "2000", "Numbers": "12509939.0"}, {"Country Name": "Zimbabwe", "Country Code": "ZWE", "Year": "2010", "Numbers": "12571128.0"}]
print("json陣列在Python的資料類型 ", type(getDatas))
for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getData['Country Code']       # 國家代碼
        population = int(float(getData['Numbers'])) # 人口數據
        print('國家代碼 =', countryCode,
              '國家名稱 =', countryName,
              '人口數 =', population)
# Out:
# json陣列在Python的資料類型  <class 'list'>
# 國家代碼 = WLD 國家名稱 = World 人口數 = 6117806174
# 國家代碼 = AFG 國家名稱 = Afghanistan 人口數 = 25951672
# 國家代碼 = ALB 國家名稱 = Albania 人口數 = 3072478
# 國家代碼 = DZA 國家名稱 = Algeria 人口數 = 30534041
# 國家代碼 = ASM 國家名稱 = American Samoa 人口數 = 57995
# 國家代碼 = AND 國家名稱 = Andorra 人口數 = 65258
# 國家代碼 = AGO 國家名稱 = Angola 人口數 = 13926705
# 國家代碼 = ATG 國家名稱 = Antigua and Barbuda 人口數 = 78536
# 國家代碼 = ARG 國家名稱 = Argentina 人口數 = 36931013
# 國家代碼 = ARM 國家名稱 = Armenia 人口數 = 3076653
# 國家代碼 = ABW 國家名稱 = Aruba 人口數 = 91031
# 國家代碼 = AUS 國家名稱 = Australia 人口數 = 19153581
# 國家代碼 = AUT 國家名稱 = Austria 人口數 = 8012068
# 國家代碼 = AZE 國家名稱 = Azerbaijan 人口數 = 8048754
# 國家代碼 = BHS 國家名稱 = Bahamas, The 人口數 = 297992
# 國家代碼 = BHR 國家名稱 = Bahrain 人口數 = 638335
# 國家代碼 = BGD 國家名稱 = Bangladesh 人口數 = 129592417
# 國家代碼 = BRB 國家名稱 = Barbados 人口數 = 268357
# 國家代碼 = BLR 國家名稱 = Belarus 人口數 = 10005803
# 國家代碼 = BEL 國家名稱 = Belgium 人口數 = 10251906
# 國家代碼 = BLZ 國家名稱 = Belize 人口數 = 250079
# 國家代碼 = BEN 國家名稱 = Benin 人口數 = 6518442
# ...

# %%
import json

fn = 'populations.json'
with open(fn) as fnObj:
    getDatas = json.load(fnObj)                     # 讀json檔案

for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getData['Country Code']       # 國家代碼
        population = int(float(getData['Numbers'])) # 人口數據
        print('國家代碼 =', countryCode,
              '國家名稱 =', countryName,
              '人口數 =', population)
# Out:
# 國家代碼 = WLD 國家名稱 = World 人口數 = 6117806174
# 國家代碼 = AFG 國家名稱 = Afghanistan 人口數 = 25951672
# 國家代碼 = ALB 國家名稱 = Albania 人口數 = 3072478
# 國家代碼 = DZA 國家名稱 = Algeria 人口數 = 30534041
# 國家代碼 = ASM 國家名稱 = American Samoa 人口數 = 57995
# 國家代碼 = AND 國家名稱 = Andorra 人口數 = 65258
# 國家代碼 = AGO 國家名稱 = Angola 人口數 = 13926705
# 國家代碼 = ATG 國家名稱 = Antigua and Barbuda 人口數 = 78536
# 國家代碼 = ARG 國家名稱 = Argentina 人口數 = 36931013
# 國家代碼 = ARM 國家名稱 = Armenia 人口數 = 3076653
# 國家代碼 = ABW 國家名稱 = Aruba 人口數 = 91031
# 國家代碼 = AUS 國家名稱 = Australia 人口數 = 19153581
# 國家代碼 = AUT 國家名稱 = Austria 人口數 = 8012068
# 國家代碼 = AZE 國家名稱 = Azerbaijan 人口數 = 8048754
# 國家代碼 = BHS 國家名稱 = Bahamas, The 人口數 = 297992
# 國家代碼 = BHR 國家名稱 = Bahrain 人口數 = 638335
# 國家代碼 = BGD 國家名稱 = Bangladesh 人口數 = 129592417
# 國家代碼 = BRB 國家名稱 = Barbados 人口數 = 268357
# 國家代碼 = BLR 國家名稱 = Belarus 人口數 = 10005803
# 國家代碼 = BEL 國家名稱 = Belgium 人口數 = 10251906
# 國家代碼 = BLZ 國家名稱 = Belize 人口數 = 250079
# 國家代碼 = BEN 國家名稱 = Benin 人口數 = 6518442
# 國家代碼 = BMU 國家名稱 = Bermuda 人口數 = 62771
# ...

# %%
import requests

r = requests.get("https://od.cdc.gov.tw/eic/Day_Confirmation_Age_County_Gender_19CoV.json", verify=False)

list_of_dicts = r.json()

for i in list_of_dicts:
    print(i["縣市"], i["性別"], i["個案研判日"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 高雄市 女 2020/01/22
# 台北市 女 2020/01/24
# 高雄市 男 2020/01/24
# 台北市 女 2020/01/26
# 彰化縣 女 2020/01/27
# 台中市 女 2020/01/28
# 彰化縣 男 2020/01/28
# 南投縣 女 2020/01/30
# 南投縣 男 2020/01/31
# 桃園市 男 2020/02/04
# 台北市 男 2020/02/06
# 台南市 女 2020/02/06
# 宜蘭縣 女 2020/02/06
# 台北市 女 2020/02/07
# 台北市 男 2020/02/07
# 台北市 男 2020/02/08
# 台北市 男 2020/02/09
# 彰化縣 男 2020/02/16
# 彰化縣 男 2020/02/16
# 台中市 男 2020/02/18
# 彰化縣 女 2020/02/18
# 台中市 女 2020/02/19
# 新北市 女 2020/02/20
# 新北市 女 2020/02/21
# 新北市 女 2020/02/21
# 新北市 男 2020/02/23
# 新北市 男 2020/02/23
# 新北市 女 2020/02/24
# 新北市 男 2020/02/24
# 新北市 男 2020/02/25
# 新北市 女 2020/02/26
# 桃園市 女 2020/02/28
# 桃園市 男 2020/02/28
# 台北市 女 2020/02/29
# 桃園市 女 2020/02/29
# 桃園市 女 2020/02/29
# ...

# %%
print(i["縣市"], i["性別"], i["個案研判日"])
# Out:
# 台北市 女 2020/05/07

# %%
import requests

r = requests.get("https://od.cdc.gov.tw/eic/Day_Confirmation_Age_County_Gender_19CoV.json", verify=False)

list_of_dicts = r.json()

for i in list_of_dicts:
    print(i["縣市"], i["性別"], i["個案研判日"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 高雄市 女 2020/01/22
# 台北市 女 2020/01/24
# 高雄市 男 2020/01/24
# 台北市 女 2020/01/26
# 彰化縣 女 2020/01/27
# 台中市 女 2020/01/28
# 彰化縣 男 2020/01/28
# 南投縣 女 2020/01/30
# 南投縣 男 2020/01/31
# 桃園市 男 2020/02/04
# 台北市 男 2020/02/06
# 台南市 女 2020/02/06
# 宜蘭縣 女 2020/02/06
# 台北市 女 2020/02/07
# 台北市 男 2020/02/07
# 台北市 男 2020/02/08
# 台北市 男 2020/02/09
# 彰化縣 男 2020/02/16
# 彰化縣 男 2020/02/16
# 台中市 男 2020/02/18
# 彰化縣 女 2020/02/18
# 台中市 女 2020/02/19
# 新北市 女 2020/02/20
# 新北市 女 2020/02/21
# 新北市 女 2020/02/21
# 新北市 男 2020/02/23
# 新北市 男 2020/02/23
# 新北市 女 2020/02/24
# 新北市 男 2020/02/24
# 新北市 男 2020/02/25
# 新北市 女 2020/02/26
# 桃園市 女 2020/02/28
# 桃園市 男 2020/02/28
# 台北市 女 2020/02/29
# 桃園市 女 2020/02/29
# 桃園市 女 2020/02/29
# ...

# %%
import requests

r = requests.get("https://od.cdc.gov.tw/eic/Day_Confirmation_Age_County_Gender_19CoV.json", verify=False)

list_of_dicts = r.json()

for i in list_of_dicts:    
	if i["縣市"] == "高雄市": 
		print(i["縣市"], i["性別"], i["個案研判日"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 高雄市 女 2020/01/22
# 高雄市 男 2020/01/24
# 高雄市 女 2020/03/16
# 高雄市 男 2020/03/16
# 高雄市 男 2020/03/17
# 高雄市 女 2020/03/18
# 高雄市 男 2020/03/18
# 高雄市 女 2020/03/19
# 高雄市 女 2020/03/21
# 高雄市 男 2020/03/23
# 高雄市 女 2020/03/24
# 高雄市 女 2020/03/24
# 高雄市 女 2020/03/25
# 高雄市 女 2020/03/27
# 高雄市 男 2020/03/27
# 高雄市 女 2020/03/28
# 高雄市 女 2020/03/28
# 高雄市 男 2020/03/28
# 高雄市 女 2020/03/29
# 高雄市 男 2020/03/29
# 高雄市 男 2020/03/30
# 高雄市 男 2020/03/31
# 高雄市 男 2020/04/01
# 高雄市 男 2020/04/07
# 高雄市 男 2020/04/11
# 高雄市 女 2020/04/13
# 高雄市 男 2020/04/19
# 高雄市 男 2020/04/19
# 高雄市 男 2020/04/19
# 高雄市 男 2020/04/19
# 高雄市 男 2020/04/19
# 高雄市 女 2020/04/21
# 高雄市 男 2020/04/21
# 高雄市 男 2020/04/23
# 高雄市 男 2020/04/24
# 高雄市 男 2020/04/25
# ...

# %%
import requests

r = requests.get("https://od.cdc.gov.tw/eic/Day_Confirmation_Age_County_Gender_19CoV.json", verify=False)

list_of_dicts = r.json()

for i in list_of_dicts:    
	if (i["縣市"] == "高雄市") && (i["性別"] == "女"): 
		print(i["縣市"], i["性別"], i["個案研判日"])
# Out:
#   File "<ipython-input-10-59363a72c516>", line 8
#     if (i["縣市"] == "高雄市") && (i["性別"] == "女"):
#                            ^
# SyntaxError: invalid syntax

# %%
import requests

r = requests.get("https://od.cdc.gov.tw/eic/Day_Confirmation_Age_County_Gender_19CoV.json", verify=False)

list_of_dicts = r.json()

for i in list_of_dicts:    
	if i["縣市"] == "高雄市": 
		if i["性別"] == "女": 
			print(i["縣市"], i["性別"], i["個案研判日"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 高雄市 女 2020/01/22
# 高雄市 女 2020/03/16
# 高雄市 女 2020/03/18
# 高雄市 女 2020/03/19
# 高雄市 女 2020/03/21
# 高雄市 女 2020/03/24
# 高雄市 女 2020/03/24
# 高雄市 女 2020/03/25
# 高雄市 女 2020/03/27
# 高雄市 女 2020/03/28
# 高雄市 女 2020/03/28
# 高雄市 女 2020/03/29
# 高雄市 女 2020/04/13
# 高雄市 女 2020/04/21
# 高雄市 女 2020/05/02
# 高雄市 女 2020/05/04

# %%
import requests

r = requests.get("https://od.cdc.gov.tw/eic/Day_Confirmation_Age_County_Gender_19CoV.json", verify=False)

list_of_dicts = r.json()

for i in list_of_dicts:    
	if i["縣市"] == "高雄市" and i["性別"] == "女": 
			print(i["縣市"], i["性別"], i["個案研判日"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 高雄市 女 2020/01/22
# 高雄市 女 2020/03/16
# 高雄市 女 2020/03/18
# 高雄市 女 2020/03/19
# 高雄市 女 2020/03/21
# 高雄市 女 2020/03/24
# 高雄市 女 2020/03/24
# 高雄市 女 2020/03/25
# 高雄市 女 2020/03/27
# 高雄市 女 2020/03/28
# 高雄市 女 2020/03/28
# 高雄市 女 2020/03/29
# 高雄市 女 2020/04/13
# 高雄市 女 2020/04/21
# 高雄市 女 2020/05/02
# 高雄市 女 2020/05/04

# %%
import json

getDatas = [{"Country Name": "World", "Country Code": "WLD", "Year": "2000", "Numbers": "6117806174.56156"}, {"Country Name": "Albania", "Country Code": "ALB", "Year": "2000", "Numbers": "3072478.0"}, {"Country Name": "Albania", "Country Code": "ALB", "Year": "2010", "Numbers": "3205579.0"}, {"Country Name": "Algeria", "Country Code": "DZA", "Year": "2000", "Numbers": "30534041.0"}, {"Country Name": "Algeria", "Country Code": "DZA", "Year": "2010", "Numbers": "35468731.0"}, {"Country Name": "American Samoa", "Country Code": "ASM", "Year": "2000", "Numbers": "57995.0"}, {"Country Name": "American Samoa", "Country Code": "ASM", "Year": "2010", "Numbers": "69154.0"}, {"Country Name": "Andorra", "Country Code": "AND", "Year": "2000", "Numbers": "65258.0"}, {"Country Name": "Andorra", "Country Code": "AND", "Year": "2010", "Numbers": "85216.0"}, {"Country Name": "Angola", "Country Code": "AGO", "Year": "2000", "Numbers": "13926705.0"}, {"Country Name": "Angola", "Country Code": "AGO", "Year": "2010", "Numbers": "19082927.0"}, {"Country Name": "Antigua and Barbuda", "Country Code": "ATG", "Year": "2000", "Numbers": "78536.0"}, {"Country Name": "Zimbabwe", "Country Code": "ZWE", "Year": "2010", "Numbers": "12571128.0"}]

for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getData['Country Code']       # 國家代碼
        population = int(float(getData['Numbers'])) # 人口數據
        print('國家代碼 =', countryCode,
              '國家名稱 =', countryName,
              '人口數 =', population)
# Out:
# 國家代碼 = WLD 國家名稱 = World 人口數 = 6117806174
# 國家代碼 = ALB 國家名稱 = Albania 人口數 = 3072478
# 國家代碼 = DZA 國家名稱 = Algeria 人口數 = 30534041
# 國家代碼 = ASM 國家名稱 = American Samoa 人口數 = 57995
# 國家代碼 = AND 國家名稱 = Andorra 人口數 = 65258
# 國家代碼 = AGO 國家名稱 = Angola 人口數 = 13926705
# 國家代碼 = ATG 國家名稱 = Antigua and Barbuda 人口數 = 78536

# %%
import json

listNumbers = [5, 10, 20, 1]            # 串列資料
tupleNumbers = (1, 5, 10, 9)            # 元組資料
jsonData1 = json.dumps(listNumbers)     # 將串列資料轉成json資料
jsonData2 = json.dumps(tupleNumbers)    # 將串列資料轉成json資料
print("串列轉換成json的陣列", jsonData1)
print("元組轉換成json的陣列", jsonData2)
print("json陣列在Python的資料類型 ", type(jsonData1))
# Out:
# 串列轉換成json的陣列 [5, 10, 20, 1]
# 元組轉換成json的陣列 [1, 5, 10, 9]
# json陣列在Python的資料類型  <class 'str'>

# %%
import json

listObj = [{'Name':'Peter', 'Age':25, 'Gender':'M'}]    # 串列資料元素是字典
jsonData = json.dumps(listObj)                          # 將串列資料轉成json資料
print("串列轉換成json的陣列", jsonData)
print("json陣列在Python的資料類型 ", type(jsonData))
print("json陣列在Python的資料類型 ", type(listObj))
# Out:
# 串列轉換成json的陣列 [{"Name": "Peter", "Age": 25, "Gender": "M"}]
# json陣列在Python的資料類型  <class 'str'>
# json陣列在Python的資料類型  <class 'list'>

# %%
import json

players = {'AStephen Curry':'Golden State Warriors',
           'EKevin Durant':'Golden State Warriors',
           'BLebron James':'Cleveland Cavaliers',
           'DJames Harden':'Houston Rockets',
           'CPaul Gasol':'San Antonio Spurs',
          }
jsonObj1 = json.dumps(players)                      # 未用排序將字典轉成json物件
jsonObj2 = json.dumps(players, sort_keys=True)      # 有用排序將字典轉成json物件
Jjj = json.dumps(players)
#print("未用排序將字典轉換成json的物件", jsonObj1)
#print("使用排序將字典轉換成json的物件", jsonObj2)
print("有排序與未排序物件是否相同    ", jsonObj1 == Jjj )
#print("json物件在Python的資料類型 ", type(jsonObj1))
# Out:
# 有排序與未排序物件是否相同     True

# %%
import json

players = {'Stephen Curry':'Golden State Warriors',
           'Kevin Durant':'Golden State Warriors',
           'Lebron James':'Cleveland Cavaliers',
           'James Harden':'Houston Rockets',
           'Paul Gasol':'San Antonio Spurs',
          }
jsonObj = json.dumps(players, sort_keys=True, indent=4)   
print(jsonObj)
# Out:
# {
#     "James Harden": "Houston Rockets",
#     "Kevin Durant": "Golden State Warriors",
#     "Lebron James": "Cleveland Cavaliers",
#     "Paul Gasol": "San Antonio Spurs",
#     "Stephen Curry": "Golden State Warriors"
# }

# %%
import json

players = {'Stephen Curry':'Golden State Warriors',
           'Kevin Durant':'Golden State Warriors',
           'Lebron James':'Cleveland Cavaliers',
           'James Harden':'Houston Rockets',
           'Paul Gasol':'San Antonio Spurs',
          }
jsonObj = json.dumps(players, sort_keys=True)   
print(jsonObj)
# Out:
# {"James Harden": "Houston Rockets", "Kevin Durant": "Golden State Warriors", "Lebron James": "Cleveland Cavaliers", "Paul Gasol": "San Antonio Spurs", "Stephen Curry": "Golden State Warriors"}

# %%
import json

players = {'Stephen Curry':'Golden State Warriors',
           'Kevin Durant':'Golden State Warriors',
           'Lebron James':'Cleveland Cavaliers',
           'James Harden':'Houston Rockets',
           'Paul Gasol':'San Antonio Spurs',
          }
jsonObj = json.dumps(players, sort_keys=True, indent=3)   
print(jsonObj)
#jsonObj = json.dumps(players, sort_keys=True, indent=1)   
#print(jsonObj)
#jsonObj = json.dumps(players, sort_keys=True, indent=2)   
#print(jsonObj)
#jsonObj = json.dumps(players, sort_keys=True, indent=3)   
#print(jsonObj)
#jsonObj = json.dumps(players, sort_keys=True, indent=4)   
#print(jsonObj)
# Out:
# {
#    "James Harden": "Houston Rockets",
#    "Kevin Durant": "Golden State Warriors",
#    "Lebron James": "Cleveland Cavaliers",
#    "Paul Gasol": "San Antonio Spurs",
#    "Stephen Curry": "Golden State Warriors"
# }

# %%
import json

jsonObj = '{"b":80, "a":25, "c":60}'    # json物件
dictObj = json.loads(jsonObj)           # 轉成Python物件
print(dictObj)
print(type(dictObj))
# Out:
# {'b': 80, 'a': 25, 'c': 60}
# <class 'dict'>

# %%
import json

obj = '{"Asia":[{"Japan":"Tokyo"},{"Taiwan":"Taipei"}]}'
json_obj = json.loads(obj)
print(json_obj)
print(json_obj["Asia"])
print(json_obj["Asia"][0])
print(json_obj["Asia"][1])
print(json_obj["Asia"][0]["Japan"])
print(json_obj["Asia"][1]["Taiwan"])
# Out:
# {'Asia': [{'Japan': 'Tokyo'}, {'Taiwan': 'Taipei'}]}
# [{'Japan': 'Tokyo'}, {'Taiwan': 'Taipei'}]
# {'Japan': 'Tokyo'}
# {'Taiwan': 'Taipei'}
# Tokyo
# Taipei

# %%
import json

obj = '{"Asia":\
        [{"Japan":"Tokyo"},\
         {"Taiwan":"Taipei"}]\
       }'
json_obj = json.loads(obj)
print(json_obj)
print(json_obj["Asia"])
print(json_obj["Asia"][0])
print(json_obj["Asia"][1])
print(json_obj["Asia"][0]["Japan"])
print(json_obj["Asia"][1]["Taiwan"])
# Out:
# {'Asia': [{'Japan': 'Tokyo'}, {'Taiwan': 'Taipei'}]}
# [{'Japan': 'Tokyo'}, {'Taiwan': 'Taipei'}]
# {'Japan': 'Tokyo'}
# {'Taiwan': 'Taipei'}
# Tokyo
# Taipei

# %%
import json

dictObj = {'b':80, 'a':25, 'c':60}      
fn = 'out1_8.json'
with open(fn, 'w') as fnObj:
    json.dump(dictObj, fnObj)

# %%
pwd
# Out:
# 'C:\\Users\\C940'

# %%
import json

obj = {"Asia":
        [{"Japan":"Tokyo"},
         {"China":"Beijing"}]
      }
fn = 'out1_9.json'
with open(fn, 'w') as fnObj:
    json.dump(obj, fnObj)

# %%
import json

dictObj = {'b':80, 'a':25, 'c':60}      
fn = 'out1_8.json'
with open(fn, 'w') as fnObj:
    json.dump(dictObj, fnObj)

# %%
import json

objlist = [{"日本":"Japan", "首都":"Tykyo"},
           {"美州":"USA", "首都":"Washington"}]

fn = 'out1_9_1.json'
with open(fn, 'w') as fnObj:
    json.dump(objlist, fnObj)

# %%
import json

objlist = [{"日本":"Japan", "首都":"Tykyo"},
           {"美州":"USA", "首都":"Washington"}]

fn = 'out1_9_2.json'
with open(fn, 'w', encoding='utf-8') as fnObj:
    json.dump(objlist, fnObj, indent=2, ensure_ascii=False)

# %%
import json

objlist = [{"日本":"Japan", "首都":"Tykyo"},
           {"美州":"USA", "首都":"Washington"}]

fn = 'out1_9_02.json'
with open(fn, 'w', encoding='utf-8') as fnObj: # 中文
    json.dump(objlist, fnObj, indent=4, ensure_ascii=False) # 格式化存檔內容

# %%
import json
      
fn = 'out1_9_2.json'
with open(fn, 'r', encoding='utf-8') as fnObj:
    data = json.load(fnObj)

print(data)
print(type(data))
# Out:
# [{'日本': 'Japan', '首都': 'Tykyo'}, {'美州': 'USA', '首都': 'Washington'}]
# <class 'list'>

# %%
import json

fn = 'login.json'
login = input("請輸入帳號 : ")
with open(fn, 'w') as fnObj:
    json.dump(login, fnObj)
    print("%s! 歡迎使用本系統! " % login)
# Out:
# 請輸入帳號 : able
# able! 歡迎使用本系統!

# %%
import json

fn = 'login.json'
with open(fn, 'r') as fnObj:
    login = json.load(fnObj)
    print("%s! 歡迎回來使用本系統! " % login)
# Out:
# able! 歡迎回來使用本系統!

# %%
import json

fn = 'login1_13.json'
try:
    with open(fn) as fnObj:
        login = json.load(fnObj)   
except Exception:
    login = input("請輸入帳號 : ") 
    with open(fn, 'w') as fnObj:
        json.dump(login, fnObj)
        print("系統已經記錄你的帳號 ")
else:
    print("%s 歡迎回來" % login)
# Out:
# 123 歡迎回來

# %%
import json

fn = 'populations.json'
with open(fn) as fnObj:
    getDatas = json.load(fnObj)                     # 讀json檔案

for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getData['Country Code']       # 國家代碼
        population = int(float(getData['Numbers'])) # 人口數據
        print('國家代碼 =', countryCode,
              '國家名稱 =', countryName,
              '人口數 =', population)
# Out:
# 國家代碼 = WLD 國家名稱 = World 人口數 = 6117806174
# 國家代碼 = AFG 國家名稱 = Afghanistan 人口數 = 25951672
# 國家代碼 = ALB 國家名稱 = Albania 人口數 = 3072478
# 國家代碼 = DZA 國家名稱 = Algeria 人口數 = 30534041
# 國家代碼 = ASM 國家名稱 = American Samoa 人口數 = 57995
# 國家代碼 = AND 國家名稱 = Andorra 人口數 = 65258
# 國家代碼 = AGO 國家名稱 = Angola 人口數 = 13926705
# 國家代碼 = ATG 國家名稱 = Antigua and Barbuda 人口數 = 78536
# 國家代碼 = ARG 國家名稱 = Argentina 人口數 = 36931013
# 國家代碼 = ARM 國家名稱 = Armenia 人口數 = 3076653
# 國家代碼 = ABW 國家名稱 = Aruba 人口數 = 91031
# 國家代碼 = AUS 國家名稱 = Australia 人口數 = 19153581
# 國家代碼 = AUT 國家名稱 = Austria 人口數 = 8012068
# 國家代碼 = AZE 國家名稱 = Azerbaijan 人口數 = 8048754
# 國家代碼 = BHS 國家名稱 = Bahamas, The 人口數 = 297992
# 國家代碼 = BHR 國家名稱 = Bahrain 人口數 = 638335
# 國家代碼 = BGD 國家名稱 = Bangladesh 人口數 = 129592417
# 國家代碼 = BRB 國家名稱 = Barbados 人口數 = 268357
# 國家代碼 = BLR 國家名稱 = Belarus 人口數 = 10005803
# 國家代碼 = BEL 國家名稱 = Belgium 人口數 = 10251906
# 國家代碼 = BLZ 國家名稱 = Belize 人口數 = 250079
# 國家代碼 = BEN 國家名稱 = Benin 人口數 = 6518442
# 國家代碼 = BMU 國家名稱 = Bermuda 人口數 = 62771
# ...

# %%
import json

fn = 'populations.json'
with open(fn) as fnObj:
    getDatas = json.load(fnObj)                     # 讀json檔案

for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getData['Country Code']       # 國家代碼
        population = int(float(getData['Numbers'])) # 人口數據
        gooo = getData[]
        print('國家代碼 =', countryCode,
              '國家名稱 =', countryName,
              '人口數 =', population)
print(gooo)
# Out:
#   File "<ipython-input-62-71641f093971>", line 12
#     gooo = getData[]
#                    ^
# SyntaxError: invalid syntax

# %%
from pygal.maps.world import COUNTRIES

for countryCode in sorted(COUNTRIES.keys()):
    print("國家代碼 :", countryCode, "  國家名稱 = ", COUNTRIES[countryCode])
# Out:
# 國家代碼 : ad   國家名稱 =  Andorra
# 國家代碼 : ae   國家名稱 =  United Arab Emirates
# 國家代碼 : af   國家名稱 =  Afghanistan
# 國家代碼 : al   國家名稱 =  Albania
# 國家代碼 : am   國家名稱 =  Armenia
# 國家代碼 : ao   國家名稱 =  Angola
# 國家代碼 : aq   國家名稱 =  Antarctica
# 國家代碼 : ar   國家名稱 =  Argentina
# 國家代碼 : at   國家名稱 =  Austria
# 國家代碼 : au   國家名稱 =  Australia
# 國家代碼 : az   國家名稱 =  Azerbaijan
# 國家代碼 : ba   國家名稱 =  Bosnia and Herzegovina
# 國家代碼 : bd   國家名稱 =  Bangladesh
# 國家代碼 : be   國家名稱 =  Belgium
# 國家代碼 : bf   國家名稱 =  Burkina Faso
# 國家代碼 : bg   國家名稱 =  Bulgaria
# 國家代碼 : bh   國家名稱 =  Bahrain
# 國家代碼 : bi   國家名稱 =  Burundi
# 國家代碼 : bj   國家名稱 =  Benin
# 國家代碼 : bn   國家名稱 =  Brunei Darussalam
# 國家代碼 : bo   國家名稱 =  Bolivia, Plurinational State of
# 國家代碼 : br   國家名稱 =  Brazil
# 國家代碼 : bt   國家名稱 =  Bhutan
# 國家代碼 : bw   國家名稱 =  Botswana
# 國家代碼 : by   國家名稱 =  Belarus
# 國家代碼 : bz   國家名稱 =  Belize
# 國家代碼 : ca   國家名稱 =  Canada
# 國家代碼 : cd   國家名稱 =  Congo, the Democratic Republic of the
# 國家代碼 : cf   國家名稱 =  Central African Republic
# ...

# %%
import json
from pygal.maps.world import COUNTRIES

def getCountryCode(countryName):
    '''輸入國家名稱回傳國家代碼'''
    for dictCode, dictName in COUNTRIES.items():    # 搜尋國家與國家代碼字典
        if dictName == countryName:
            return dictCode                         # 如果找到則回傳國家代碼
    return None                                     # 找不到則回傳None

fn = 'populations.json'
with open(fn) as fnObj:
    getDatas = json.load(fnObj)                     # 讀取人口數據json檔案

for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getCountryCode(countryName)
        population = int(float(getData['Numbers'])) # 人口數       
        if countryCode != None:
            print(countryCode, ":", population)     # 國家名稱相符
        else:
            print(countryName," 名稱不吻合:")       # 國家名稱不吻合
# Out:
# World  名稱不吻合:
# af : 25951672
# al : 3072478
# dz : 30534041
# American Samoa  名稱不吻合:
# ad : 65258
# ao : 13926705
# Antigua and Barbuda  名稱不吻合:
# ar : 36931013
# am : 3076653
# Aruba  名稱不吻合:
# au : 19153581
# at : 8012068
# az : 8048754
# Bahamas, The  名稱不吻合:
# bh : 638335
# bd : 129592417
# Barbados  名稱不吻合:
# by : 10005803
# be : 10251906
# bz : 250079
# bj : 6518442
# Bermuda  名稱不吻合:
# bt : 572150
# Bolivia  名稱不吻合:
# ba : 3694221
# bw : 1758101
# br : 174425502
# bn : 327173
# bg : 8170923
# bf : 12294582
# bi : 6375154
# kh : 12447158
# cm : 15678792
# ca : 30770661
# cv : 438098
# Cayman Islands  名稱不吻合:
# cf : 3701785
# td : 8223089
# Channel Islands  名稱不吻合:
# cl : 15420422
# cn : 1262645259
# co : 39764430
# Comoros  名稱不吻合:
# Congo, Dem. Rep.  名稱不吻合:
# Congo, Rep.  名稱不吻合:
# cr : 3919918
# ci : 16581844
# hr : 4426628
# cu : 11104631
# Curacao  名稱不吻合:
# cy : 943448
# cz : 10272763
# dk : 5340588
# dj : 732112
# Dominica  名稱不吻合:
# do : 8592212
# ec : 12345909
# ...

# %%
import pygal.maps.world

worldMap = pygal.maps.world.World()         # 建立世界地圖物件
worldMap.title = 'Taiwan in the Map'         # 世界地圖標題
worldMap.add('Taiwan',['tw'])                # 標記中國
worldMap.render_to_file('out1_17.svg')      # 儲存地圖檔案

# %%
import pygal.maps.world

worldMap = pygal.maps.world.World()         # 建立世界地圖物件
worldMap.title = 'Taiwan/Japan/Thailand'     # 世界地圖標題
worldMap.add('Asia',['tw', 'jp', 'th'])     # 標記Asia
worldMap.render_to_file('out1_18.svg')      # 儲存地圖檔案

# %%
import pygal.maps.world

worldMap = pygal.maps.world.World()                         # 建立世界地圖物件
worldMap.title = ' Asia, Europe, Africa, and North America' # 世界地圖標題
worldMap.add('Asia',['cn', 'jp', 'th'])                     # 標記Asia
worldMap.add('Europe',['fr', 'de', 'it'])                   # 標記Europe
worldMap.add('Africa',['eg', 'ug', 'ng'])                   # 標記Africa
worldMap.add('North America',['ca', 'us', 'mx'])            # 標記北美洲
worldMap.render_to_file('out1_19.svg')                      # 儲存地圖檔案

# %%
import pygal.maps.world

worldMap = pygal.maps.world.World()                     # 建立世界地圖物件
worldMap.title = 'Taiwan/Japan/United States'  # 世界地圖標題
worldMap.add('Asia',{'tw':1262645000,
                     'jp':126870000,
                     'us':63155029})                    # 標記人口資訊
worldMap.render_to_file('out1_20.svg')                  # 儲存地圖檔案

# %%
import json
import pygal.maps.world
from pygal.maps.world import COUNTRIES

def getCountryCode(countryName):
    '''輸入國家名稱回傳國家代碼'''
    for dictCode, dictName in COUNTRIES.items():    # 搜尋國家與國家代碼字典
        if dictName == countryName:
            return dictCode                         # 如果找到則回傳國家代碼
    return None                                     # 找不到則回傳None

fn = 'populations.json'
with open(fn) as fnObj:
    getDatas = json.load(fnObj)                     # 讀取人口數據json檔案

dictData = {}                                       # 定義地圖使用的字典
for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getCountryCode(countryName)
        population = int(float(getData['Numbers'])) # 人口數       
        if countryCode != None:
            dictData[countryCode] = population      # 代碼:人口數據加入字典

worldMap = pygal.maps.world.World()
worldMap.title = "World Population in 2000"
worldMap.add('Year 2000', dictData)
worldMap.render_to_file('out1_21.svg')              # 儲存地圖檔案

# %%
import json
import pygal.maps.world
from pygal.maps.world import COUNTRIES

def getCountryCode(countryName):
    '''輸入國家名稱回傳國家代碼'''
    for dictCode, dictName in COUNTRIES.items():    # 搜尋國家與國家代碼字典
        if dictName == countryName:
            return dictCode                         # 如果找到則回傳國家代碼
    return None                                     # 找不到則回傳None

fn = 'populations.json'
with open(fn) as fnObj:
    getDatas = json.load(fnObj)                     # 讀取人口數據json檔案

dictData = {}                                       # 定義地圖使用的字典
for getData in getDatas:
    if getData['Year'] == '2000':                   # 篩選2000年的數據
        countryName = getData['Country Name']       # 國家名稱
        countryCode = getCountryCode(countryName)
        population = int(float(getData['Numbers'])) # 人口數       
        if countryCode != None:
            dictData[countryCode] = population      # 代碼:人口數據加入字典

dict1, dict2 = {}, {}                               # 定義人口數分級的字典
for code, population in dictData.items():
    if population > 100000000:
        dict1[code] = population                    # 人口數大於1000000000
    else:
        dict2[code] = population                    # 人口數小於1000000000

worldMap = pygal.maps.world.World()
worldMap.title = "World Population in 2000"
worldMap.add('Over 1000000000', dict1)
worldMap.add('Under 1000000000', dict2)
worldMap.render_to_file('out1_22.svg')              # 儲存地圖檔案

# %%
import xmltodict

with open('myxml.xml', encoding='utf-8') as f:
    txt = xmltodict.parse(f.read())
print(txt)
# Out:
# OrderedDict([('深智數位', OrderedDict([('總經理', 'John'), ('編輯部', 'Lai'), ('業務部', OrderedDict([('國外', OrderedDict([('@主管', 'Linda'), ('人數', '10人')])), ('國內', 'Mary')]))]))])

# %%
import xmltodict

with open('myxml.xml', encoding='utf-8') as f:
    txt = xmltodict.parse(f.read())
#print(txt,'\n')
#print(txt['深智數位'],'\n')
print('總經理 : ',txt['深智數位']['總經理'])
print('總編輯 : ',txt['深智數位']['編輯部'],'\n')
#print(txt['深智數位']['業務部'],'\n')
#print(txt['深智數位']['業務部']['國外'],'\n')
print('國外業務主管 : ',txt['深智數位']['業務部']['國外']['@主管'])
print('國外業務人數 : ',txt['深智數位']['業務部']['國外']['人數'])
print('國內業務主管 : ',txt['深智數位']['業務部']['國內'])
# Out:
# 總經理 :  John
# 總編輯 :  Lai
#
# 國外業務主管 :  Linda
# 國外業務人數 :  10人
# 國內業務主管 :  Mary
