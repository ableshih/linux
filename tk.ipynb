# %%
import tkinter as tk

def createNewWindow():
    newWindow = tk.Toplevel(app)

app = tk.Tk()
app.state('zoomed')
buttonExample = tk.Button(app, 
              text="Create new window",
              command=createNewWindow)
buttonExample.pack()

app.mainloop()

# %%
# pip install pillow

import io    
from PIL import Image, ImageTk    
import tkinter as tk    

def resize( w_box, h_box, pil_image):
    w, h = pil_image.size
    f1 = 1.0*w_box/w 
    f2 = 1.0*h_box/h    
    factor = min([f1, f2])   
    width = int(w*factor)    
    height = int(h*factor)    
    return pil_image.resize((width, height), Image.ANTIALIAS)    

def createNewWindow():
    newWindow = tk.Toplevel(root)
    labelExample = tk.Label(newWindow, text = "New Window")
    buttonExample = tk.Button(newWindow, text = "New Window button")

    labelExample.pack()
    buttonExample.pack()

def callback1():
    print ("click 1!")
    '''
    root1 = tk.Tk()
    root1.title("Hi BOM1")
    root1.geometry("800x600")

    newWindow = tk.Toplevel(root1)
    #labelExample = tk.Label(newWindow, text = "New Window")
    #buttonExample = tk.Button(newWindow, text = "New Window button")
    #def callbackA():
    #pil_img5 = Image.open(r'1.jpg')
    #pil_img_RS5 = resize( w_box, h_box, pil_img5)
    #tk_img5 = ImageTk.PhotoImage(pil_img_RS5)
    #lab5 = tk.Button(newWindow, padx=1, pady=1, image=tk_img5, command = callback5)
    
    img_png = tk.PhotoImage(file = '1.jpg')
    lab5 = tk.Button(newWindow, text ="Hello", image=img_png , command = helloCallBack)
    lab5.place(x=0,y=0)#,anchor='w')
    #lab5.pack()

    pil_img6 = Image.open(r'2.jpg')
    pil_img_RS6 = resize( w_box, h_box, pil_img6)
    tk_img6 = ImageTk.PhotoImage(pil_img_RS6)
    lab6 = tk.Button(newWindow, padx=1, pady=1, image=tk_img6, command = callback6)
    lab6.place(x=400,y=0)#,anchor='w')

    pil_img7 = Image.open(r'3.jpg')
    pil_img_RS7 = resize( w_box, h_box, pil_img7)
    tk_img7 = ImageTk.PhotoImage(pil_img_RS7)
    lab7 = tk.Button(newWindow, padx=1, pady=1, image=tk_img7, command = callback7)
    lab7.place(x=0,y=300)#,anchor='w')

    pil_img8 = Image.open(r'4.jpg')
    pil_img_RS8 = resize( w_box, h_box, pil_img8)
    tk_img8 = ImageTk.PhotoImage(pil_img_RS8)
    lab8 = tk.Button(newWindow, padx=1, pady=1, image=tk_img8, command = callback8)
    lab8.place(x=400,y=300)#,anchor='w')
    
'''

    #labelExample.pack()
    #buttonExample.pack()
    #root1.mainloop()

def callback2():
    print ("click 2!")
    #root.destroy() # 關閉 Tkinter 視窗
    #self.root.geometry('400x350')

def callback3():
    print ("click 3!")

def callback4():
    print ("click 4!")
def callback5():
    print ("click 5!")
def callback6():
    print ("click 6!")
def callback7():
    print ("click 7!")
def callback8():
    print ("click 8!")
def callback9():
    print ("click 9!")


root = tk.Tk()
root.title("Hi BOM")
screenWidth,screenHeight = root.maxsize()
print(screenWidth,screenHeight) # 1366 768
root.geometry("800x600")
root.state('zoomed')
#app = tk.Tk()

w_box = 400
h_box = 300    

pil_img1 = Image.open(r'1.jpg')
pil_img_RS1 = resize( w_box, h_box, pil_img1)
tk_img1 = ImageTk.PhotoImage(pil_img_RS1)
lab1 = tk.Button(root, padx=1, pady=1, image=tk_img1, command = callback1)
lab1.place(x=0,y=0)

pil_img2 = Image.open(r'2.jpg')
pil_img_RS2 = resize( w_box, h_box, pil_img2)
tk_img2 = ImageTk.PhotoImage(pil_img_RS2)
lab2 = tk.Button(root, padx=1, pady=1, image=tk_img2, command = callback2)
lab2.place(x=400,y=0)#,anchor='w')

pil_img3 = Image.open(r'3.jpg')
pil_img_RS3 = resize( w_box, h_box, pil_img3)
tk_img3 = ImageTk.PhotoImage(pil_img_RS3)
lab3 = tk.Button(root, padx=1, pady=1, image=tk_img3, command = callback3)
lab3.place(x=0,y=300)#,anchor='w')

pil_img4 = Image.open(r'4.jpg')
pil_img_RS4 = resize( w_box, h_box, pil_img4)
tk_img4 = ImageTk.PhotoImage(pil_img_RS4)
lab4 = tk.Button(root, padx=1, pady=1, image=tk_img4, command = callback4)
lab4.place(x=400,y=300)#,anchor='w')

root.mainloop()
# Out:
# 1366 768
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-20-0379005484f3> in <module>
#     103 pil_img_RS1 = resize( w_box, h_box, pil_img1)
#     104 tk_img1 = ImageTk.PhotoImage(pil_img_RS1)
# --> 105 lab1 = tk.Button(root, padx=1, pady=1, image=tk_img1, command = callback1)
#     106 lab1.place(x=0,y=0)
#     107
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in __init__(self, master, cnf, **kw)
#    2367             overrelief, state, width
#    2368         """
# -> 2369         Widget.__init__(self, master, 'button', cnf, kw)
#    2370
#    2371     def flash(self):
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2297             del cnf[k]
#    2298         self.tk.call(
# -> 2299             (widgetName, self._w) + extra + self._options(cnf))
#    2300         for k, v in classes:
# ...

# %%
import tkinter as tk

def createNewWindow():
    newWindow = tk.Toplevel(app)
    labelExample = tk.Label(newWindow, text = "New Window")
    buttonExample = tk.Button(newWindow, text = "New Window button")

    labelExample.pack()
    buttonExample.pack()

app = tk.Tk()
app.title("Hi BOM")
app.geometry("800x600")

buttonExample = tk.Button(app, 
              text="Create new window",
              command=createNewWindow)
buttonExample.pack()

app.mainloop()

# %%
import tkinter as tk
from tkinter.simpledialog import askstring, askinteger, askfloat

# 接收一個整數
def print_integer():
    res = askinteger("Spam", "Egg count", initialvalue=12*12)
    print(res)
# 接收一個浮點數
def print_float():
    res = askfloat("Spam", "Egg weight\n(in tons)", minvalue=1, maxvalue=100)
    print(res)
# 接收一個字串
def print_string():
    res = askstring("Spam", "Egg label")
    print(res)

root = tk.Tk()
tk.Button(root, text='取一個字串', command=print_string).pack()
tk.Button(root, text='取一個整數', command=print_integer).pack()
tk.Button(root, text='取一個浮點數', command=print_float).pack()
root.mainloop()
# Out:
# None
# 144

# %%
# root.destory() 類方法關閉 Tkinter 視窗
try:
    import Tkinter as tk
except:
    import tkinter as tk
class Test():
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('400x350')
        button = tk.Button(self.root, 
                          text = 'Click and Quit', 
                          command=self.quit)
        button.pack()
        self.root.mainloop()

    def quit(self):
        self.root.destroy() # 關閉 Tkinter 視窗
        
app = Test()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter.messagebox import showinfo

class Application(ttk.Frame):
    def __init__(self, master):
        ttk.Frame.__init__(self, master)
        self.pack()

        self.button = ttk.Button(self)
        self.button["text"] = "Click Me!"
        self.button["command"] = self.popup_hello
        self.button.pack()
    
    def popup_hello(self1):
        #showinfo("Hello", "Hello Tk!")
        def __init__(self1, master1):
            ttk.Frame.__init__(self1, master1)
            self1.pack()

            self1.button = ttk.Button(self1)
            self1.button["text"] = "Click Me!"
            self1.button["command"] = self1.popup_hello1
            self1.button.pack()
            
        def popup_hello1(self1):
            showinfo("Hello", "Hellonnn Tk!")
            
root = tk.Tk()
app = Application(root)
#app.geometry("800x600")
root.geometry('400x350')

root.mainloop()

# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
import tkinter as tk

root = tk.Tk()
root.title('应用程序窗口')        #窗口标题
root.resizable(False, False)    #固定窗口大小
windowWidth = 800               #获得当前窗口宽
windowHeight = 500              #获得当前窗口高
print(screenWidth,screenHeight)
screenWidth,screenHeight = root.maxsize()     #获得屏幕宽和高
print(screenWidth,screenHeight)
geometryParam = '%dx%d+%d+%d'%(windowWidth, windowHeight, (screenWidth-windowWidth)/2, (screenHeight - windowHeight)/2)
print(geometryParam)
root.geometry(geometryParam)    #设置窗口大小及偏移坐标
root.wm_attributes('-topmost',1)#窗口置顶

#label文本
label_text = tk.Label(root, text = '文本');
label_text.pack();

#label图片
#img_png = tk.PhotoImage(file='C:\\Users\\V570\\1.png')
img_png1 = tk.PhotoImage(file = 'C:\\Users\\V570\\1.png')
#img_gif = tk.PhotoImage(file = '1.jpg')
label_img = tk.Label(root, image = img_png1)
label_img.pack()

#不带图button
button = tk.Button(root, text = '不带图按钮')
button.pack()

#带图button，image
#button_img_gif = tk.PhotoImage(file='C:\\Users\\V570\\4.jpg')
img_png = tk.PhotoImage(file = 'C:\\Users\\V570\\1.png')
button_img = tk.Button(root, image = img_png, text = '带图按钮')
button_img.pack()

#带图button，bitmap
button_bitmap = tk.Button(root, bitmap = 'error', text = '带图按钮')
button_bitmap.pack()

root.mainloop()
# Out:
# 1366 768
# 1366 768
# 800x500+283+134

# %%
import tkinter as tk

class FullScreenApp(object):
    def __init__(self, master, **kwargs):
        self.master=master
        pad=3
        self._geom='200x200+0+0'
        master.geometry("{0}x{1}+0+0".format(
            master.winfo_screenwidth()-pad, master.winfo_screenheight()-pad))
        master.bind('<Escape>',self.toggle_geom)            
    def toggle_geom(self,event):
        geom=self.master.winfo_geometry()
        print(geom,self._geom)
        self.master.geometry(self._geom)
        self._geom=geom
#tk.attributes("-fullscreen", True)
root=tk.Tk()
app=FullScreenApp(root)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-014e51ff822f> in <module>
#      14         self.master.geometry(self._geom)
#      15         self._geom=geom
# ---> 16 tk.attributes("-fullscreen", True)
#      17 root=tk.Tk()
#      18 app=FullScreenApp(root)
#
# AttributeError: module 'tkinter' has no attribute 'attributes'

# %%
import sys
if sys.version_info[0] == 2:  # Just checking your Python version to import Tkinter properly.
    from Tkinter import *
else:
    from tkinter import *


class Fullscreen_Window:

    def __init__(self):
        self.tk = Tk()
        self.tk.attributes('-zoomed', True)  # This just maximizes it so we can see the window. It's nothing to do with fullscreen.
        self.frame = Frame(self.tk)
        self.frame.pack()
        self.state = False
        self.tk.bind("<F11>", self.toggle_fullscreen)
        self.tk.bind("<Escape>", self.end_fullscreen)

    def toggle_fullscreen(self, event=None):
        self.state = not self.state  # Just toggling the boolean
        self.tk.attributes("-fullscreen", self.state)
        return "break"

    def end_fullscreen(self, event=None):
        self.state = False
        self.tk.attributes("-fullscreen", False)
        return "break"

if __name__ == '__main__':
w = Fullscreen_Window()
w.tk.mainloop()
# Out:
#   File "<ipython-input-2-4db13f620147>", line 30
#     w = Fullscreen_Window()
#     ^
# IndentationError: expected an indented block

# %%
# importing only those functions which 
# are needed 
# https://www.geeksforgeeks.org/python-geometry-method-in-tkinter/
# root.geometry 的用法

from tkinter import Tk, mainloop, TOP 
from tkinter.ttk import Button 

# creating tkinter window 
root = Tk() 

# creating fixed geometry of the 
# tkinter window with dimensions 150x200 
root.geometry('200x150+400+300') # 不可留空白 視窗 200 x 150 視窗 距離原點偏移 往右400, 往下300

button = Button(root, text = 'Geeks') 
button.pack(side = TOP, pady = 5) # button 向上 上下間隔 5 pixel

mainloop()

# %%
# 傳值 判斷
import tkinter 
from tkinter import *

def callback(input): 
    if input.isdigit(): 
        print(input) 
        return True
    elif input is '1': 
        print(input) 
        return True
    else: 
        print(input) 
        return False

root = Tk() 
e = Entry(root) 
e.place(x = 50, y = 50) 
reg = root.register(callback) 
e.config(validate ="key",  validatecommand =(reg, '% P')) 
root.mainloop()
# Out:
# \ P

# %%
# 開圖 按鍵 關視窗 無框
from tkinter import *
from PIL import ImageTk ,Image

def callback():
    base.destroy() # 關閉 Tkinter 視窗

base = Tk()
base.title('Start Button')

img=ImageTk.PhotoImage(Image.open ("1.jpg"))
lab=Label(image=img)
lab.pack()

button=Button(base,text='exit',command=callback)
button.pack()
base.wm_attributes('-fullscreen','true') # 無框
base.mainloop()

# %%
# 無邊框
from tkinter import *

class Application(Frame):
    def __init__(self,master=None, *args, **kwargs):
        Frame.__init__(self,master, *args, **kwargs)
        self.grid()
        self.createWidgets()
        self.flag=True
        self.transparent=False
        self.top = self.winfo_toplevel()
    def overturn(self):
        '''
        self.top.update_idletasks()
        self.top.overrideredirect(self.flag)
        self.flag=not self.flag #switch
        '''
    def createWidgets(self):
        self.canvas = Canvas(self, bg='green')
        self.canvas.pack()
        self.flagButton = Button(self, text='try this', bg='green', command=self.overturn)
        self.flagButton.pack()

app = Application()
app.master.title("sample application")
app.mainloop()

# %%
# 視窗最大化
from tkinter import *
root = Tk()
root.state('zoomed') # 視窗最大化
root.mainloop()

# %%
# 系統解析 視窗
try:
    import Tkinter as tk
except:
    import tkinter as tk

app = tk.Tk()
app.title("Frame Window Size Frozen")
# 無框

screenWidth,screenHeight = app.maxsize() # 取得系統解析
print(screenWidth,screenHeight) # 1366 768

app.minsize(width=screenWidth, height=screenHeight)
app.maxsize(width=screenWidth, height=screenHeight)
#print(width,height)
#app.minsize(width=screenWidth, height=screenHeight)
#app.maxsize(width=600, height=400)
app.wm_attributes('-fullscreen','true') # 無框
app.mainloop()
# Out:
# 1366 768

# %%
# https://www.delftstack.com/zh/howto/python-tkinter/how-to-freeze-the-tkinter-window-frame-size/
# 不可調整視窗大小
try:
    import Tkinter as tk
except:
    import tkinter as tk

app = tk.Tk()
app.title("Frame Window Size Frozen")
app.geometry('300x200')
#app.wm_attributes('-fullscreen','true') # 無框
app.resizable(width=False, height=False) # 凍結視窗 不可調整視窗大小
app.mainloop()

# %%
# tk 無邊框 python
from tkinter import *
class Application(Frame):
    def __init__(self,master=None, *args, **kwargs):
        Frame.__init__(self,master, *args, **kwargs)
        self.grid()
        self.createWidgets()
        self.flag=True
        self.transparent=False
        self.top = self.winfo_toplevel()
    def overturn(self):
        self.top.update_idletasks()
        #self.top.overrideredirect(self.flag)
        self.flag=not self.flag #switch

    def createWidgets(self):
        self.canvas = Canvas(self, bg='green')
        self.canvas.pack()
        self.flagButton = Button(self, text='try this', bg='green', command=self.overturn)
        self.flagButton.pack()
app = Application()
app.master.title("sample application")
app.mainloop()
